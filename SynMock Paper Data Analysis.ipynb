# %% [raw]
# ###PreProcessing Reads

# %%
# !amptk ion -i mock3.ion.fastq --barcode_fasta mock3.barcodes.fa --min_len 100 -o ion3
# Out:
# -------------------------------------------------------
# [01:48:59 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [01:49:00 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [01:49:00 PM]: Foward primer: AGTGARTCATCGAATCTTTG,  Rev comp'd rev primer: GCATATCAATAAGCGGAGGA
# [01:49:00 PM]: Loading FASTQ Records
# [01:49:05 PM]: 4,332,502 reads (3.3 GB)
# -------------------------------------------------------
# [02:32:41 PM]: Concatenating Demuxed Files
# [02:33:12 PM]: 4,332,502 total reads
# [02:33:12 PM]: 3,115,600 valid Barcode
# [02:33:12 PM]: 2,915,936 Fwd Primer found, 2,158,790 Rev Primer found
# [02:33:12 PM]: 36,792 discarded too short (< 100 bp)
# [02:33:12 PM]: 2,879,144 valid output reads
# [02:33:20 PM]: Found 19 barcoded samples
#                 Sample:  Count
#               m3-766-1:  205305
#        m3-mock3-32000b:  189175
#         m3-mock3-16000:  183277
#         m3-mock3-3200a:  181421
#               m3-301-2:  170879
# ...

# %%
#Now process first illumina run containing termX samples + biomock
# !amptk illumina -i termX_miseqA -o m4a --min_len 100 --read_length 300 --cleanup
# Out:
# -------------------------------------------------------
# [02:33:23 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:33:23 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:33:23 PM]: Gzipped files detected, uncompressing
# [02:34:48 PM]: Merging Overlaping Pairs using USEARCH
# [02:34:48 PM]: working on sample m4A-301-1 (Read Length: 300)
# [02:34:59 PM]: 270,478 reads passed (100.0%)
# [02:34:59 PM]: working on sample m4A-301-2 (Read Length: 300)
# [02:35:10 PM]: 296,226 reads passed (100.0%)
# [02:35:10 PM]: working on sample m4A-500-1 (Read Length: 300)
# [02:35:24 PM]: 334,852 reads passed (100.0%)
# [02:35:24 PM]: working on sample m4A-500-2 (Read Length: 300)
# [02:35:35 PM]: 275,990 reads passed (100.0%)
# [02:35:35 PM]: working on sample m4A-712-1 (Read Length: 300)
# [02:35:46 PM]: 265,985 reads passed (100.0%)
# [02:35:46 PM]: working on sample m4A-712-2 (Read Length: 300)
# [02:35:56 PM]: 242,161 reads passed (100.0%)
# ...

# %%
#Now process first illumina run containing termX samples + biomock but run with 1 mismatch binning
# !amptk illumina -i miseqA_1mm -o m4a1m --min_len 100 --read_length 300 --cleanup
# Out:
# -------------------------------------------------------
# [07:17:12 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [07:17:12 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [07:17:12 PM]: Gzipped files detected, uncompressing
# [07:19:02 PM]: Merging Overlaping Pairs using USEARCH
# [07:19:02 PM]: working on sample m4a-1mm-301-1 (Read Length: 300)
# [07:19:14 PM]: 283,491 reads passed (100.0%)
# [07:19:14 PM]: working on sample m4a-1mm-301-2 (Read Length: 300)
# [07:19:28 PM]: 310,136 reads passed (100.0%)
# [07:19:28 PM]: working on sample m4a-1mm-500-1 (Read Length: 300)
# [07:19:44 PM]: 351,169 reads passed (100.0%)
# [07:19:44 PM]: working on sample m4a-1mm-500-2 (Read Length: 300)
# [07:19:56 PM]: 289,626 reads passed (100.0%)
# [07:19:56 PM]: working on sample m4a-1mm-712-1 (Read Length: 300)
# [07:20:08 PM]: 277,133 reads passed (100.0%)
# [07:20:08 PM]: working on sample m4a-1mm-712-2 (Read Length: 300)
# [07:20:19 PM]: 259,415 reads passed (100.0%)
# ...

# %%
#process illumina run B; this was the same 4 libraries run on a different run, shows no index bleed
# !amptk illumina -i termX_miseqB -o m4b --min_len 100 --read_length 300 --cleanup
# Out:
# -------------------------------------------------------
# [03:24:16 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:24:16 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:24:16 PM]: Merging Overlaping Pairs using USEARCH
# [03:24:16 PM]: working on sample m4b-744-1 (Read Length: 300)
# [03:24:24 PM]: 191,554 reads passed (100.0%)
# [03:24:24 PM]: working on sample m4b-744-2 (Read Length: 300)
# [03:24:31 PM]: 156,694 reads passed (100.0%)
# [03:24:31 PM]: working on sample m4b-766-1 (Read Length: 300)
# [03:24:38 PM]: 165,809 reads passed (100.0%)
# [03:24:38 PM]: working on sample m4b-766-2 (Read Length: 300)
# [03:24:44 PM]: 145,681 reads passed (100.0%)
# [03:24:44 PM]: Stripping primers and trim/pad to 250 bp
# [03:24:44 PM]: splitting the job over 8 cpus, but this may still take awhile
# [03:24:44 PM]: Foward primer: GTGARTCATCGAATCTTTG,  Rev comp'd rev primer: GCATATCAATAAGCGGAGGA
# -------------------------------------------------------
# ...

# %%
#now demux miseq run 3, remade libraries from same amplicons with different barcodes
# !amptk illumina -i termX_miseqC -o m4c --min_len 100 --read_length 300 --cleanup
# Out:
# -------------------------------------------------------
# [03:30:28 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:30:28 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:30:28 PM]: Gzipped files detected, uncompressing
# [03:32:04 PM]: Merging Overlaping Pairs using USEARCH
# [03:32:04 PM]: working on sample m4C-301-1 (Read Length: 300)
# [03:32:18 PM]: 314,816 reads passed (100.0%)
# [03:32:18 PM]: working on sample m4C-301-2 (Read Length: 300)
# [03:32:35 PM]: 388,353 reads passed (100.0%)
# [03:32:35 PM]: working on sample m4C-500-1 (Read Length: 300)
# [03:32:48 PM]: 300,488 reads passed (100.0%)
# [03:32:48 PM]: working on sample m4C-500-2 (Read Length: 300)
# [03:33:01 PM]: 298,858 reads passed (100.0%)
# [03:33:01 PM]: working on sample m4C-712-1 (Read Length: 300)
# [03:33:14 PM]: 307,694 reads passed (100.0%)
# [03:33:14 PM]: working on sample m4C-712-2 (Read Length: 300)
# [03:33:26 PM]: 302,851 reads passed (100.0%)
# ...

# %%
#now finally one more run, where we used SynMock on same samples using Ion torrent
# !amptk ion -i mock5.ion.fastq --barcode_fasta mock5.barcodes.fa --min_len 100 -o ion5
# Out:
# -------------------------------------------------------
# [01:32:43 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [01:32:43 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [01:32:43 PM]: Foward primer: AGTGARTCATCGAATCTTTG,  Rev comp'd rev primer: GCATATCAATAAGCGGAGGA
# [01:32:43 PM]: Loading FASTQ Records
# [01:32:48 PM]: 4,341,392 reads (3.3 GB)
# -------------------------------------------------------
# [02:20:44 PM]: Concatenating Demuxed Files
# [02:21:18 PM]: 4,341,392 total reads
# [02:21:18 PM]: 3,230,560 valid Barcode
# [02:21:18 PM]: 2,925,109 Fwd Primer found, 2,329,942 Rev Primer found
# [02:21:18 PM]: 35,658 discarded too short (< 100 bp)
# [02:21:18 PM]: 2,889,451 valid output reads
# [02:21:27 PM]: Found 24 barcoded samples
#                 Sample:  Count
#    m5-SynMock1-mock3.0:  270701
#               m5-712-2:  232495
#               m5-301-2:  186706
# m5-SynMock1.736-1.736-2:  173385
#               m5-301-1:  173161
# ...

# %%
#concatenate all miseq runs
# !cat m4a.demux.fq m4b.demux.fq m4c.demux.fq > miseq.fq

# %%
# !amptk show -i miseq.fq
# Out:
# ----------------------------------
# Found 64 barcoded samples
#               Sample:  Count
#            m4C-757-2:  390122
#            m4C-301-2:  385896
#            m4C-755-2:  351946
#        m4a-1mm-500-1:  348835
#     m4C-mock3-32000a:  348020
#        m4a-1mm-766-2:  339808
#            m4A-500-1:  332586
#            m4A-766-2:  321816
#        m4a-1mm-755-1:  321611
#        m4a-1mm-766-1:  317212
#            m4C-736-2:  314792
#            m4C-301-1:  312792
#            m4C-757-1:  310890
# m4a-1mm-mock3-32000a:  310372
#        m4a-1mm-301-2:  307544
#            m4C-712-1:  306776
#        m4a-1mm-755-2:  306489
#     m4C-mock3-32000b:  305175
#            m4A-755-1:  302871
#            m4A-766-1:  302038
#            m4C-712-2:  300925
# m4a-1mm-mock3-32000b:  300285
#      m4C-mock3-16000:  299132
#            m4C-500-1:  299131
#            m4C-500-2:  297249
#        m4a-1mm-757-1:  297145
#  m4a-1mm-mock3-16000:  295022
#     m4A-mock3-32000a:  294813
# ...

# %%
#cluster the miseq data
# !amptk cluster -i miseq.fq -o miseq
# Out:
# -------------------------------------------------------
# [08:33:58 AM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [08:33:58 AM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [08:33:58 AM]: Loading FASTQ Records
# [08:34:09 AM]: 12,352,805 reads (6.2 GB)
# [08:34:09 AM]: Quality Filtering, expected errors < 1.0
# [08:38:33 AM]: 9,739,836 reads passed
# [08:38:33 AM]: De-replication (remove duplicate reads)
# [08:39:03 AM]: 362,215 reads passed
# [08:39:04 AM]: Clustering OTUs (UPARSE)
# [08:39:27 AM]: 2,212 OTUs
# [08:39:27 AM]: Cleaning up padding from OTUs
# [08:39:27 AM]: Mapping Reads to OTUs and Building OTU table
# [09:18:22 AM]: 10,607,514 reads mapped to OTUs (86%)
# -------------------------------------------------------
# OTU Clustering Script has Finished Successfully
# -------------------------------------------------------
# Clustered OTUs: /Users/jon/projects/synmock_paper/miseq.cluster.otus.fa
# ...

# %%
#get taxonomy for miseq OTUs
# !amptk taxonomy -f miseq.cluster.otus.fa -o miseq -d ITS2
# Out:
# -------------------------------------------------------
# [09:18:46 AM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [09:18:46 AM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [09:18:46 AM]: Loading FASTA Records
# [09:18:46 AM]: 2,212 OTUs
# [09:18:46 AM]: Global alignment OTUs with usearch_global (USEARCH)
# [09:19:07 AM]: Classifying OTUs with UTAX (USEARCH)
# [09:19:07 AM]: Classifying OTUs with SINTAX (USEARCH)
# [09:24:20 AM]: Generating phylogenetic tree
# [09:24:29 AM]: Taxonomy finished: miseq.taxonomy.txt
# [09:24:29 AM]: OTUs with taxonomy: miseq.otus.taxonomy.fa
# [09:24:29 AM]: OTU phylogeny: miseq.tree.phy
# -------------------------------------------------------

# %%
#concatenate all ion runs
# !cat ion3.demux.fq ion5.demux.fq > ion.fq

# %%
#cluster the ion data
# !amptk cluster -i ion.fq -o ion
# Out:
# -------------------------------------------------------
# [02:46:03 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:46:03 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:46:03 PM]: Loading FASTQ Records
# [02:46:08 PM]: 5,768,595 reads (2.9 GB)
# [02:46:08 PM]: Quality Filtering, expected errors < 1.0
# [02:48:13 PM]: 3,077,553 reads passed
# [02:48:13 PM]: De-replication (remove duplicate reads)
# [02:48:23 PM]: 110,375 reads passed
# [02:48:24 PM]: Clustering OTUs (UPARSE)
# [02:48:33 PM]: 1,382 OTUs
# [02:48:33 PM]: Cleaning up padding from OTUs
# [02:48:33 PM]: Mapping Reads to OTUs and Building OTU table
# [02:59:43 PM]: 4,739,372 reads mapped to OTUs (82%)
# -------------------------------------------------------
# OTU Clustering Script has Finished Successfully
# -------------------------------------------------------
# Clustered OTUs: /Users/jon/projects/synmock_paper/ion.cluster.otus.fa
# ...

# %%
#get taxonomy for ion OTUs
# !amptk taxonomy -f ion.cluster.otus.fa -o ion -d ITS2
# Out:
# -------------------------------------------------------
# [03:03:09 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:03:09 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:03:09 PM]: Loading FASTA Records
# [03:03:09 PM]: 1,382 OTUs
# [03:03:09 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [03:03:23 PM]: Classifying OTUs with UTAX (USEARCH)
# [03:03:23 PM]: Classifying OTUs with SINTAX (USEARCH)
# [03:07:04 PM]: Generating phylogenetic tree
# [03:07:09 PM]: Taxonomy finished: ion.taxonomy.txt
# [03:07:09 PM]: OTUs with taxonomy: ion.otus.taxonomy.fa
# [03:07:09 PM]: OTU phylogeny: ion.tree.phy
# -------------------------------------------------------

# %%
#generate OTU table for each of the runs using the combined OTUs from either miseq or ion
#now slice the OTU table for each of the runs, Ion3, Miseq4A, Miseq4C, Ion5
#load original table, not the name changed version for normal processing
import pandas as pd
from natsort import natsorted

miseqdf = pd.read_csv('miseq.otu_table.txt', sep='\t', index_col=0)
iondf = pd.read_csv('ion.otu_table.txt', sep='\t', index_col=0)

ion3 = ['m3-301-1', 'm3-301-2', 'm3-500-1', 'm3-500-2', 'm3-712-1', 'm3-712-2', 
        'm3-736-1', 'm3-736-2', 'm3-744-1', 'm3-744-2', 'm3-755-1', 'm3-755-2',
        'm3-757-2', 'm3-766-1', 'm3-766-2', 'm3-mock3-16000']
ion3df = iondf.reindex(columns=ion3, index=natsorted(iondf.index))
ion3df.to_csv('ion3.otu_table.txt', sep='\t')
miseq4a = ['m4A-301-1', 'm4A-301-2', 'm4A-500-1', 'm4A-500-2', 'm4A-712-1', 
           'm4A-712-2', 'm4A-736-1', 'm4A-736-2', 'm4A-744-1', 'm4A-744-2', 
           'm4A-755-1', 'm4A-755-2', 'm4A-757-1', 'm4A-757-2', 'm4A-766-1', 'm4A-766-2', 'm4A-mock3-16000']
miseq4adf = miseqdf.reindex(columns=miseq4a, index=natsorted(miseqdf.index))
miseq4adf.to_csv('miseq4a.otu_table.txt', sep='\t')
miseq4c = ['m4C-301-1', 'm4C-301-2', 'm4C-500-1', 'm4C-500-2', 'm4C-712-1', 
           'm4C-712-2', 'm4C-736-1', 'm4C-736-2', 'm4C-744-1', 'm4C-744-2', 
           'm4C-755-1', 'm4C-755-2', 'm4C-757-1', 'm4C-757-2', 'm4C-766-1', 'm4C-766-2', 'm4C-mock3-16000']
miseq4cdf = miseqdf.reindex(columns=miseq4c, index=natsorted(miseqdf.index))
miseq4cdf.to_csv('miseq4c.otu_table.txt', sep='\t')
ion5 = ['m5-301-1', 'm5-301-2', 'm5-500-1', 'm5-500-2', 'm5-712-1', 
        'm5-712-2', 'm5-736-1', 'm5-736-2', 'm5-744-1', 'm5-744-2', 
        'm5-755-1', 'm5-755-2', 'm5-757-1', 'm5-757-2', 'm5-766-1', 'm5-766-2', 'm5-SynMock2-8000']
ion5df = iondf.reindex(columns=ion5, index=natsorted(iondf.index))
ion5df.to_csv('ion5.otu_table.txt', sep='\t')

# %%
#now filter these datasets for raw and filtered (no subtraction, index-bleed 0.5% for all - because extra mocks in each run)
# !amptk filter -f miseq.cluster.otus.fa -i miseq4a.otu_table.txt -o miseq4a -b m4A-mock3-16000 -m mock3 -p 0.005 -c in
# !amptk filter -f miseq.cluster.otus.fa -i miseq4c.otu_table.txt -o miseq4c -b m4C-mock3-16000 -m mock3 -p 0.005 -c in
# !amptk filter -f ion.cluster.otus.fa -i ion3.otu_table.txt -o ion3 -b m3-mock3-16000 -m mock3 -p 0.005 -c in
# !amptk filter -f ion.cluster.otus.fa -i ion5.otu_table.txt -o ion5 -b m5-SynMock2-8000 -m synmock -p 0.005
# Out:
# -------------------------------------------------------
# [03:12:23 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:12:23 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:12:23 PM]: Loading OTU table: miseq4a.otu_table.txt
# [03:12:23 PM]: OTU table contains 2205 OTUs
# [03:12:23 PM]: Mapping OTUs to Mock Community (USEARCH)
# [03:12:23 PM]: Sorting OTU table naturally
# [03:12:23 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [03:12:23 PM]: Normalizing OTU table to number of reads per sample
# [03:12:23 PM]: Index bleed, samples into mock: 0.054002%.
# [03:12:23 PM]: Overwriting auto detect index-bleed, setting to 0.500000%
# [03:12:24 PM]: Filtering OTU table down to 1865 OTUs
# [03:12:24 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# OTU Table Stats:      miseq4a.stats.txt
# ...

# %%
#now generate the raw OTU table from the sorted (original output)
import pandas as pd
from natsort import natsorted
import subprocess
#pull out header for indexing later
base = 'ion3'
platform = 'ion'
    
#now load sorted "raw" OTU table into dataframe
sort = pd.read_csv(base+'.sorted.txt', sep='\t', index_col=0)

#now we want to drop last column
header = ['m3-301-1', 'm3-301-2', 'm3-500-1', 'm3-500-2', 'm3-712-1', 'm3-712-2', 
        'm3-736-1', 'm3-736-2', 'm3-744-1', 'm3-744-2', 'm3-755-1', 'm3-755-2',
        'm3-757-2', 'm3-766-1', 'm3-766-2']
cleaned = sort.reindex(columns=header, index=natsorted(sort.index))

#now drop OTUs where they are all zero
fs = cleaned.sum(axis=0)
filtered = pd.DataFrame(cleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(sort), len(sort.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv(base+'.sorted.nomock.txt', sep='\t')

#now convert to biom
cmd = ['amptk', 'taxonomy', '-f', platform+'.cluster.otus.fa', '-o', base+'_raw', '-i', base+'.sorted.nomock.txt', '-d', 'ITS2','-m','mapping/'+base+'.mapping_file.txt', '-t', platform+'.taxonomy.txt']
subprocess.call(cmd)
# Out:
# 1367 16 1227 15
# 0

# %%
#now generate the raw OTU table from the sorted (original output)
import pandas as pd
from natsort import natsorted
import subprocess
#pull out header for indexing later
base = 'ion5'
platform = 'ion'
    
#now load sorted "raw" OTU table into dataframe
sort = pd.read_csv(base+'.sorted.txt', sep='\t', index_col=0)

#now we want to drop last column
header = ['m5-301-1', 'm5-301-2', 'm5-500-1', 'm5-500-2', 'm5-712-1', 
        'm5-712-2', 'm5-736-1', 'm5-736-2', 'm5-744-1', 'm5-744-2', 
        'm5-755-1', 'm5-755-2', 'm5-757-1', 'm5-757-2', 'm5-766-1', 'm5-766-2']
cleaned = sort.reindex(columns=header, index=natsorted(sort.index))

#now drop OTUs where they are all zero
fs = cleaned.sum(axis=0)
filtered = pd.DataFrame(cleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(sort), len(sort.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv(base+'.sorted.nomock.txt', sep='\t')

#now convert to biom
cmd = ['amptk', 'taxonomy', '-f', platform+'.cluster.otus.fa', '-o', base+'_raw', '-i', base+'.sorted.nomock.txt', '-d', 'ITS2','-m','mapping/'+base+'.mapping_file.txt', '-t', platform+'.taxonomy.txt']
subprocess.call(cmd)
# Out:
# 1382 17 1235 16
# 0

# %%
#now generate the raw OTU table from the sorted (original output)
import pandas as pd
from natsort import natsorted
import subprocess
#pull out header for indexing later
base = 'miseq4a'
platform = 'miseq'
    
#now load sorted "raw" OTU table into dataframe
sort = pd.read_csv(base+'.sorted.txt', sep='\t', index_col=0)

#now we want to drop last column
header = ['m4A-301-1', 'm4A-301-2', 'm4A-500-1', 'm4A-500-2', 'm4A-712-1', 
           'm4A-712-2', 'm4A-736-1', 'm4A-736-2', 'm4A-744-1', 'm4A-744-2', 
           'm4A-755-1', 'm4A-755-2', 'm4A-757-1', 'm4A-757-2', 'm4A-766-1', 'm4A-766-2']
cleaned = sort.reindex(columns=header, index=natsorted(sort.index))

#now drop OTUs where they are all zero
fs = cleaned.sum(axis=0)
filtered = pd.DataFrame(cleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(sort), len(sort.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv(base+'.sorted.nomock.txt', sep='\t')

#now convert to biom
cmd = ['amptk', 'taxonomy', '-f', platform+'.cluster.otus.fa', '-o', base+'_raw', '-i', base+'.sorted.nomock.txt', '-d', 'ITS2','-m','mapping/'+base+'.mapping_file.txt', '-t', platform+'.taxonomy.txt']
subprocess.call(cmd)
# Out:
# 2205 17 2094 16
# 0

# %%
#now generate the raw OTU table from the sorted (original output)
import pandas as pd
from natsort import natsorted
import subprocess
#pull out header for indexing later
base = 'miseq4c'
platform = 'miseq'
    
#now load sorted "raw" OTU table into dataframe
sort = pd.read_csv(base+'.sorted.txt', sep='\t', index_col=0)

#now we want to drop last column
header = ['m4C-301-1', 'm4C-301-2', 'm4C-500-1', 'm4C-500-2', 'm4C-712-1', 
           'm4C-712-2', 'm4C-736-1', 'm4C-736-2', 'm4C-744-1', 'm4C-744-2', 
           'm4C-755-1', 'm4C-755-2', 'm4C-757-1', 'm4C-757-2', 'm4C-766-1', 'm4C-766-2']
cleaned = sort.reindex(columns=header, index=natsorted(sort.index))

#now drop OTUs where they are all zero
fs = cleaned.sum(axis=0)
filtered = pd.DataFrame(cleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(sort), len(sort.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv(base+'.sorted.nomock.txt', sep='\t')

#now convert to biom
cmd = ['amptk', 'taxonomy', '-f', platform+'.cluster.otus.fa', '-o', base+'_raw', '-i', base+'.sorted.nomock.txt', '-d', 'ITS2','-m','mapping/'+base+'.mapping_file.txt', '-t', platform+'.taxonomy.txt']
subprocess.call(cmd)
# Out:
# 2205 17 2035 16
# 0

# %%
#run taxonomy command on all output
# !amptk taxonomy -f ion3.filtered.otus.fa -i ion3.final.txt -o ion3 -d ITS2 -t ion.taxonomy.txt -m mapping/ion3.mapping_file.txt
# !amptk taxonomy -f ion5.filtered.otus.fa -i ion5.final.txt -o ion5 -d ITS2 -t ion.taxonomy.txt -m mapping/ion5.mapping_file.txt
# !amptk taxonomy -f miseq4a.filtered.otus.fa -i miseq4a.final.txt -o miseq4a -d ITS2 -t miseq.taxonomy.txt -m mapping/m4a.mapping_file.txt
# !amptk taxonomy -f miseq4c.filtered.otus.fa -i miseq4c.final.txt -o miseq4c -d ITS2 -t miseq.taxonomy.txt -m mapping/m4c.mapping_file.txt
# Out:
# -------------------------------------------------------
# [03:16:15 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:16:15 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:16:15 PM]: Loading FASTA Records
# [03:16:15 PM]: 1,136 OTUs
# [03:16:15 PM]: Appending taxonomy to OTU table and OTUs
# [03:16:15 PM]: Generating phylogenetic tree
# [03:16:18 PM]: Taxonomy finished: ion.taxonomy.txt
# [03:16:18 PM]: Classic OTU table with taxonomy: ion3.otu_table.taxonomy.txt
# [03:16:19 PM]: BIOM OTU table created: ion3.biom
# [03:16:19 PM]: OTUs with taxonomy: ion3.otus.taxonomy.fa
# [03:16:19 PM]: OTU phylogeny: ion3.tree.phy
# -------------------------------------------------------
# -------------------------------------------------------
# [03:16:20 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:16:20 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:16:20 PM]: Loading FASTA Records
# [03:16:20 PM]: 1,155 OTUs
# ...

# %%
#now convert all to meta transposition for R/michelle's scripts
# !amptk meta -i ion3_raw.otu_table.taxonomy.txt -m all_data.meta.csv -o ion3_raw.meta.csv
# !amptk meta -i ion3.otu_table.taxonomy.txt -m all_data.meta.csv -o ion3_filtered.meta.csv
# !amptk meta -i ion5_raw.otu_table.taxonomy.txt -m all_data.meta.csv -o ion5_raw.meta.csv
# !amptk meta -i ion5.otu_table.taxonomy.txt -m all_data.meta.csv -o ion5_filtered.meta.csv
# !amptk meta -i miseq4a_raw.otu_table.taxonomy.txt -m all_data.meta.csv -o miseq4a_raw.meta.csv
# !amptk meta -i miseq4a.otu_table.taxonomy.txt -m all_data.meta.csv -o miseq4a_filtered.meta.csv
# !amptk meta -i miseq4c_raw.otu_table.taxonomy.txt -m all_data.meta.csv -o miseq4c_raw.meta.csv
# !amptk meta -i miseq4c.otu_table.taxonomy.txt -m all_data.meta.csv -o miseq4c_filtered.meta.csv
# Out:
# Working on complete OTU table: found 1227 OTUs
# ERROR m4C-301-1, m4C-301-2, m4C-500-1, m4C-500-2, m4C-712-1, m4C-712-2, m4C-736-1, m4C-736-2, m4C-744-1, m4C-744-2, m4C-755-1, m4C-755-2, m4C-757-1, m4C-757-2, m4C-766-1, m4C-766-2, m4C-mock3-16000, m4C-mock3-32000a, m4C-mock3-32000b, m4C-stds, m4A-301-1, m4A-301-2, m4A-500-1, m4A-500-2, m4A-712-1, m4A-712-2, m4A-736-1, m4A-736-2, m4A-744-1, m4A-744-2, m4A-755-1, m4A-755-2, m4A-757-1, m4A-757-2, m4A-766-1, m4A-766-2, m4A-mock3-16000, m4A-mock3-32000a, m4A-mock3-32000b, m4A-stds, m3-mock3-3200a, m3-mock3-16000, m3-mock3-32000b, m3-stds, m5-301-1, m5-301-2, m5-500-1, m5-500-2, m5-712-1, m5-712-2, m5-736-1, m5-736-2, m5-744-1, m5-744-2, m5-755-1, m5-755-2, m5-757-1, m5-757-2, m5-766-1, m5-766-2, m5-SynMock1-8000, m5-SynMock2-8000, m5-mock3.0-16000, m5-mock3.5-16000: not found in OTU table. Names must max exactly.
# Working on complete OTU table: found 1136 OTUs
# ...

# %%
#to look at mock communities across all runs, pull out reads and map to mock2 sequences
# !amptk select -i all.reads.fq -o mock.samples.demux.fa --format fasta -l m3-stds m3-mock3-16000 m3-mock3-3200a m3-mock3-32000b m4A-stds m4A-mock3-16000 m4A-mock3-32000a m4A-mock3-32000b m4C-stds m4C-mock3-16000 m4C-mock3-32000a m4C-mock3-32000b
# Out:
# Kept 2965759 reads out of 17459832 total reads

# %%
#map these reads to mock community sequences
# !vsearch --usearch_global mock.samples.demux.fa --id 0.97 --db /Users/jon/amptk/DB/amptk_mock2.fa --otutabout figure1.mock.otu_table.txt
# Out:
# vsearch v2.4.2_osx_x86_64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file /Users/jon/amptk/DB/amptk_mock2.fa 100%
# 14847 nt in 26 seqs, min 335, max 680, avg 571
# Masking 100%
# Counting unique k-mers 100%
# Creating index of unique k-mers 100%
# Searching 100%
# Matching query sequences: 2464948 of 2965759 (83.11%)
# Writing OTU table (classic) 100%

# %%
#now look at synmock and biomock from run 5, it was run several different ways, multiple combinatons of plasmids
#as well as mixing plasmids of the mocks together and also mixing with other samples
#asking question here about what happens when complexity of community is greater than just 12 

#first get both synmock and biomock3 together to use as database, get only ITS2 portion
# !cat $HOME/amptk/DB/amptk_mock3.fa $HOME/amptk/DB/amptk_synmock.fa > mock3_synmock.fa
#little hack here but use amptk database to trim primers
# !amptk database -i mock3_synmock.fa --format off --keep_all --primer_mismatch 2 -o mock3_synmock.trimmed
#change synmock names
# !gsed 's/>mock_/>Synmock/g' $HOME/amptk/DB/mock3_synmock.trimmed.extracted.fa > mock3_synmock.trim.fa
# Out:
# -------------------------------------------------------
# [08:45:30 AM]: Searching for primers, this may take awhile: Fwd: fITS7  Rev: ITS4
# [08:45:30 AM]: 35 records loaded
# [08:45:30 AM]: Using 8 cpus to process data
# [08:45:30 AM]: 35 records passed (100.00%)
# -------------------------------------------------------

# %%
#ok now map ion reads to the combined mock sequences
# !amptk select -i ion5.demux.fq -o ion5.mocks.demux.fa --format fasta -l m5-SynMock1-8000 m5-SynMock1-mock3.0 m5-SynMock1-mock3.5 m5-SynMock1.736-1.736-2 m5-SynMock2-8000 m5-SynMock2.757-1.757-2 m5-mock3.0-16000 m5-mock3.5-16000
# !vsearch --usearch_global ion5.mocks.demux.fa --db mock3_synmock.trim.fa --id 0.97 --strand plus --otutabout ion5.mock.otu_table.txt
# Out:
# Kept 1046220 reads out of 2889451 total reads
# vsearch v2.4.2_osx_x86_64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file mock3_synmock.trim.fa 100%
# 10010 nt in 35 seqs, min 161, max 411, avg 286
# Masking 100%
# Counting unique k-mers 100%
# Creating index of unique k-mers 100%
# Searching 100%
# Matching query sequences: 705289 of 1046220 (67.41%)
# Writing OTU table (classic) 100%

# %%
#reorder and sort table
import pandas as pd
from natsort import natsorted

#load table
df = pd.read_csv('syn.final.txt', sep='\t', index_col=0)
headers = ['m5-SynMock1-8000', 'm5-SynMock1.736-1.736-2','m5-SynMock2-8000', 'm5-SynMock2.757-1.757-2']
df2 = df.reindex(columns=headers, index=natsorted(df.index))
mocks = []
for x in df2.index:
    if x.startswith('mock'):
        mocks.append(x)
otus = [item for item in df2.index if item not in mocks]

df3 = df2.reindex(columns=headers, index=mocks)
df3.to_csv('ion5.onlymocks.txt', sep='\t')
#draw heatmap here of only the mock members, add the rest manually?
# !amptk heatmap -i ion5.onlymocks.txt -o ion5.only.mock.pdf -m heatmap -d tsv --color YlOrRd --annotate
df4 = df2.reindex(columns=headers, index=otus)
#get number of OTUs from df4 as well as total reads
reads = df4.sum(axis=0)
reads.name ="Other OTUs"
otu_count = df4[df4 > 0].count(axis=0, numeric_only=True)
otu_count.name = "Number of OTUs"
#print reads
print otu_count
#now append the read numbers to df3 dataframe
df3 = df3.append(reads)
print df3
total_reads = df3.sum(axis=0)
print total_reads
df3.to_csv('ion5.mock.clean.otu_table.txt', sep='\t')

#regular heatmap
# !amptk heatmap -i ion5.mock.clean.otu_table.txt -o ion5.mock.pdf -m heatmap -d tsv --color YlOrRd --annotate
#normalized to 100,000 reads heatmap
# !amptk heatmap -i ion5.mock.clean.otu_table.txt -o ion5.mock.normalized.pdf --debug --normalize syn.stats.txt -m heatmap -d tsv --color YlOrRd --annotate
# Out:
# m5-SynMock1-8000            26
# m5-SynMock1.736-1.736-2    213
# m5-SynMock2-8000            28
# m5-SynMock2.757-1.757-2    209
# Name: Number of OTUs, dtype: int64
#                             m5-SynMock1-8000  m5-SynMock1.736-1.736-2  \
# #OTU ID
# mock_1_pident=100.0_OTU141              3499                     1012
# mock_2_pident=100.0_OTU46              12252                     3156
# mock_3_pident=100.0_OTU23              11937                     3629
# mock_4_pident=100.0_OTU31              11339                     4041
# mock_5_pident=100.0_OTU27               6720                     2272
# mock_6_pident=100.0_OTU30               4915                     1475
# mock_7_pident=100.0_OTU36              13725                     6725
# mock_8_pident=100.0_OTU12              16065                     5802
# mock_9_pident=100.0_OTU34               5449                     1516
# mock_10_pident=100.0_OTU37              3635                      816
# ...

# %%
#clean up the miseq and ion combined runs to look for index bleed, filter without removing anything
# !amptk filter -i miseq.otu_table.txt -f miseq.cluster.otus.fa -p 0 -o miseq -b m4A-stds -m mock2 --keep_mock
# !amptk filter -i ion.otu_table.txt -f ion.cluster.otus.fa -p 0 -o ion -b m3-stds -m mock2 --keep_mock
# Out:
# -------------------------------------------------------
# [04:29:53 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [04:29:54 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [04:29:54 PM]: Loading OTU table: miseq.otu_table.txt
# [04:29:54 PM]: OTU table contains 2205 OTUs
# [04:29:54 PM]: Mapping OTUs to Mock Community (USEARCH)
# [04:29:54 PM]: Sorting OTU table naturally
# [04:29:54 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [04:29:54 PM]: Normalizing OTU table to number of reads per sample
# [04:29:54 PM]: Index bleed, mock into samples: 87.777681%.  Index bleed, samples into mock: 0.372015%.
# [04:29:54 PM]: Overwriting auto detect index-bleed, setting to 0.000000%
# [04:29:57 PM]: Filtering OTU table down to 2139 OTUs
# [04:29:57 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# ...

# %%
#want to measure index bleed, also have 1 mismatch dataset, so generate OTU table for that dataset
# !vsearch --fastq_filter m4a1m.demux.fq -fastaout m4a1m.demux.fa
# !vsearch --usearch_global m4a1m.demux.fa --db miseq.cluster.otus.fa --id 0.97 --strand plus --otutabout miseq4a1m.otu_table.txt
# !rm m4a1m.demux.fa
# Out:
# vsearch v2.4.2_osx_x86_64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading input file 100%
# 5921159 sequences kept (of which 0 truncated), 0 sequences discarded.
# vsearch v2.4.2_osx_x86_64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file miseq.cluster.otus.fa 100%
# 542602 nt in 2212 seqs, min 100, max 250, avg 245
# Masking 100%
# Counting unique k-mers 100%
# Creating index of unique k-mers 100%
# Searching 100%
# Matching query sequences: 5589169 of 5921159 (94.39%)
# Writing OTU table (classic) 100%

# %%
#run through filtering so it is sorted etc
# !amptk filter -i miseq4a1m.otu_table.txt -f miseq.cluster.otus.fa -p 0 -b m4a-1mm-stds -m mock2 --keep_mock -o miseq4a1m
# Out:
# -------------------------------------------------------
# [04:37:45 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [04:37:45 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [04:37:45 PM]: Loading OTU table: miseq4a1m.otu_table.txt
# [04:37:45 PM]: OTU table contains 2113 OTUs
# [04:37:45 PM]: Mapping OTUs to Mock Community (USEARCH)
# [04:37:45 PM]: Sorting OTU table naturally
# [04:37:45 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [04:37:45 PM]: Normalizing OTU table to number of reads per sample
# [04:37:45 PM]: Index bleed, mock into samples: 75.585583%.  Index bleed, samples into mock: 0.402020%.
# [04:37:45 PM]: Overwriting auto detect index-bleed, setting to 0.000000%
# [04:37:46 PM]: Filtering OTU table down to 1904 OTUs
# [04:37:46 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# ...

# %%
#need to measure index bleed, lets start with ion dataset
import pandas as pd
import numpy as np
from natsort import natsorted
#now load sorted "raw" OTU table into dataframe
df = pd.read_csv('ion.final.txt', sep='\t', index_col=0)
#print list(df.columns.values)
#print len(df)
#okay, so 1367 OTUs in entire data set, lets trim this down to only run 3, as that one is labeled here with biomock
keepers = ['m3-301-1', 'm3-301-2', 'm3-500-1', 'm3-500-2', 'm3-712-1', 'm3-712-2', 
           'm3-736-1', 'm3-736-2', 'm3-744-1', 'm3-744-2', 'm3-755-1', 'm3-755-2', 
           'm3-757-2', 'm3-766-1', 'm3-766-2', 'm3-mock3-3200a', 'm3-mock3-16000', 'm3-mock3-32000b', 'm3-stds']
mock_samples = ['m3-mock3-3200a', 'm3-mock3-16000', 'm3-mock3-32000b', 'm3-stds']
samples = [item for item in keepers if item not in mock_samples]
#print samples
df2 = df.reindex(columns=keepers, index=natsorted(df.index))

#now drop OTUs where they are all zero
df3 = df2.loc[(df2 != 0).any(1)]
mock_otus = []
for x in df3.index:
    if x.startswith('mock'):
        if not x.startswith('mock3'): #mock3 is actually in some of the samples so can't use for index-bleed measurment
            mock_otus.append(x)
#now slice into two tables containing only mocks and calculate index-bleed
bleed_counts = df3.reindex(columns=samples, index=mock_otus)
bleed_sum = bleed_counts.values.sum()
real_counts = df3.reindex(columns=mock_samples, index=mock_otus)
real_sum = real_counts.values.sum()
index_bleed = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed out of mock: %f%% (%i out of %i)" % (index_bleed, bleed_sum, real_sum)

#now try to to do the opposite, count number of times that samples move into mock
#first generate list of mock otus
sample_otus = []
for x in df3.index:
    if not x.startswith('mock'):
        sample_otus.append(x)
#slice first to samples, further trim list of only things found in mocks, would be spurious or chimeras
sampledf = df3.reindex(columns=samples, index=sample_otus)
sampledf = sampledf.loc[(sampledf != 0).any(1)]
cleaned_otus = sampledf.index
#print len(cleaned_otus), len(sample_otus)

#now using new list grab counts in mock
bleed_counts = df3.reindex(columns=mock_samples, index=cleaned_otus)
bleed_counts = bleed_counts.loc[(bleed_counts != 0).any(1)]
bleed_sum = bleed_counts.values.sum()
#print len(bleed_counts.index), bleed_sum

#finally go back to samples and get read counts for the ovlerlapping otus
real_counts = df3.reindex(columns=samples, index=bleed_counts.index)
real_sum = real_counts.values.sum()
index_bleed2 = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed into mock: %f%% (%i out of %i)" % (index_bleed2, bleed_sum, real_sum)
print "Total index-bleed: %f%%" % (index_bleed + index_bleed2)
# Out:
# Index-bleed out of mock: 0.025328% (114 out of 450086)
# Index-bleed into mock: 0.009703% (115 out of 1185245)
# Total index-bleed: 0.035031%

# %%
#map synthetic mock onto this dataset
# !amptk filter -i ion.otu_table.txt -f ion.cluster.otus.fa -p 0 -o syn -b m5-SynMock2-8000 -m synmock --keep_mock
# Out:
# -------------------------------------------------------
# [05:26:11 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [05:26:11 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [05:26:11 PM]: Loading OTU table: ion.otu_table.txt
# [05:26:11 PM]: OTU table contains 1382 OTUs
# [05:26:11 PM]: Mapping OTUs to Mock Community (USEARCH)
# [05:26:11 PM]: Sorting OTU table naturally
# [05:26:11 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [05:26:12 PM]: Normalizing OTU table to number of reads per sample
# [05:26:12 PM]: Index bleed, mock into samples: 76.549668%.  Index bleed, samples into mock: 1.201976%.
# [05:26:12 PM]: Overwriting auto detect index-bleed, setting to 0.000000%
# [05:26:13 PM]: Filtering OTU table down to 1382 OTUs
# [05:26:13 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# ...

# %%
#now try on the ion5 dataset
#need to measure index bleed, lets start with ion dataset
import pandas as pd
import numpy as np
from natsort import natsorted
import sys
#now load sorted "raw" OTU table into dataframe
df = pd.read_csv('syn.final.txt', sep='\t', index_col=0)
#print list(df.columns.values)
#sys.exit(1)
#print len(df)
#okay, so 1367 OTUs in entire data set, lets trim this down to only run 3, as that one is labeled here with biomock
keepers = ['m5-301-1', 'm5-301-2', 'm5-500-1', 'm5-500-2', 'm5-712-1', 'm5-712-2', 'm5-736-1', 'm5-736-2', 
           'm5-744-1', 'm5-744-2', 'm5-755-1', 'm5-755-2', 'm5-757-1', 'm5-757-2', 'm5-766-1', 'm5-766-2', 
           'm5-SynMock1-8000', 'm5-SynMock1-mock3.0', 'm5-SynMock1-mock3.5', 'm5-SynMock1.736-1.736-2', 
           'm5-SynMock2-8000', 'm5-SynMock2.757-1.757-2', 'm5-mock3.0-16000', 'm5-mock3.5-16000']
mock_samples = ['m5-SynMock2-8000', 'm5-SynMock2.757-1.757-2', 'm5-SynMock1-8000', 
                'm5-SynMock1-mock3.0', 'm5-SynMock1-mock3.5', 'm5-SynMock1.736-1.736-2']
samples = [item for item in keepers if item not in mock_samples]
#print samples
df2 = df.reindex(columns=keepers, index=natsorted(df.index))

#now drop OTUs where they are all zero
df3 = df2.loc[(df2 != 0).any(1)]
mock_otus = []
for x in df3.index:
    if 'mock' in x: #note this is different here as I'm also including mock chimeras as based on synthetic mock
        mock_otus.append(x)
#now slice into two tables containing only mocks and calculate index-bleed
bleed_counts = df3.reindex(columns=samples, index=mock_otus)
bleed_sum = bleed_counts.values.sum()
real_counts = df3.reindex(columns=mock_samples, index=mock_otus)
real_sum = real_counts.values.sum()
index_bleed = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed out of mock: %f%% (%i out of %i)" % (index_bleed, bleed_sum, real_sum)

#now try to to do the opposite, count number of times that samples move into mock
#first generate list of mock otus
sample_otus = []
for x in df3.index:
    if not 'mock' in x: #note this is different here as I'm also including mock chimeras as based on synthetic mock
        sample_otus.append(x)
clean_mocks = ['m5-SynMock2-8000', 'm5-SynMock1-8000',]
#slice first to samples, further trim list of only things found in mocks, would be spurious or chimeras
sampledf = df3.reindex(columns=samples, index=sample_otus)
sampledf = sampledf.loc[(sampledf != 0).any(1)]
cleaned_otus = sampledf.index
#print len(cleaned_otus), len(sample_otus)

#now using new list grab counts in mock
bleed_counts = df3.reindex(columns=clean_mocks, index=cleaned_otus)
bleed_counts = bleed_counts.loc[(bleed_counts != 0).any(1)]
bleed_sum = bleed_counts.values.sum()
#print len(bleed_counts.index), bleed_sum

#finally go back to samples and get read counts for the ovlerlapping otus
real_counts = df3.reindex(columns=samples, index=bleed_counts.index)
real_sum = real_counts.values.sum()
index_bleed2 = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed into mock: %f%% (%i out of %i)" % (index_bleed2, bleed_sum, real_sum)
print "Total index-bleed: %f%%" % (index_bleed + index_bleed2)
# Out:
# Index-bleed out of mock: 0.043358% (224 out of 516625)
# Index-bleed into mock: 0.029789% (87 out of 292054)
# Total index-bleed: 0.073147%

# %%
#need to measure index bleed of miseq data now, trying 1 mismatch dataset first
import pandas as pd
import numpy as np
from natsort import natsorted
import sys
#now load sorted "raw" OTU table into dataframe
df = pd.read_csv('miseq4a1m.final.txt', sep='\t', index_col=0)
#print list(df.columns.values)
#sys.exit(1)
#print len(df)
#okay, so 1367 OTUs in entire data set, lets trim this down to only run 3, as that one is labeled here with biomock
keepers = ['m4a-1mm-301-1', 'm4a-1mm-301-2', 'm4a-1mm-500-1', 'm4a-1mm-500-2', 'm4a-1mm-712-1', 
           'm4a-1mm-712-2', 'm4a-1mm-736-1', 'm4a-1mm-736-2', 'm4a-1mm-744-1', 'm4a-1mm-744-2', 
           'm4a-1mm-755-1', 'm4a-1mm-755-2', 'm4a-1mm-757-1', 'm4a-1mm-757-2', 'm4a-1mm-766-1', 
           'm4a-1mm-766-2', 'm4a-1mm-mock3-16000', 'm4a-1mm-mock3-32000a', 'm4a-1mm-mock3-32000b', 'm4a-1mm-stds']
mock_samples = ['m4a-1mm-mock3-16000', 'm4a-1mm-mock3-32000a', 'm4a-1mm-mock3-32000b', 'm4a-1mm-stds']
samples = [item for item in keepers if item not in mock_samples]
#print samples
df2 = df.reindex(columns=keepers, index=natsorted(df.index))

#now drop OTUs where they are all zero
df3 = df2.loc[(df2 != 0).any(1)]
mock_otus = []
for x in df3.index:
    if x.startswith('mock'):
        if not x.startswith('mock3'): #mock3 is actually in some of the samples so can't use for index-bleed measurment
            mock_otus.append(x)
#now slice into two tables containing only mocks and calculate index-bleed
bleed_counts = df3.reindex(columns=samples, index=mock_otus)
bleed_sum = bleed_counts.values.sum()
real_counts = df3.reindex(columns=mock_samples, index=mock_otus)
real_sum = real_counts.values.sum()
index_bleed = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed out of mock: %f%% (%i out of %i)" % (index_bleed, bleed_sum, real_sum)

#now try to to do the opposite, count number of times that samples move into mock
#first generate list of mock otus
sample_otus = []
for x in df3.index:
    if not x.startswith('mock'):
        sample_otus.append(x)
#slice first to samples, further trim list of only things found in mocks, would be spurious or chimeras
sampledf = df3.reindex(columns=samples, index=sample_otus)
sampledf = sampledf.loc[(sampledf != 0).any(1)]
cleaned_otus = sampledf.index
#print len(cleaned_otus), len(sample_otus)

#now using new list grab counts in mock
bleed_counts = df3.reindex(columns=mock_samples, index=cleaned_otus)
bleed_counts = bleed_counts.loc[(bleed_counts != 0).any(1)]
bleed_sum = bleed_counts.values.sum()
#print len(bleed_counts.index), bleed_sum

#finally go back to samples and get read counts for the ovlerlapping otus
real_counts = df3.reindex(columns=samples, index=bleed_counts.index)
real_sum = real_counts.values.sum()
index_bleed2 = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed into mock: %f%% (%i out of %i)" % (index_bleed2, bleed_sum, real_sum)
print "Total index-bleed: %f%%" % (index_bleed + index_bleed2)
# Out:
# Index-bleed out of mock: 0.329377% (3281 out of 996124)
# Index-bleed into mock: 0.024575% (734 out of 2986781)
# Total index-bleed: 0.353952%

# %%
#need to measure index bleed of miseq data now, trying 0 mismatch miseqA dataset first
import pandas as pd
import numpy as np
from natsort import natsorted
import sys
#now load sorted "raw" OTU table into dataframe
df = pd.read_csv('miseq.final.txt', sep='\t', index_col=0)
#print list(df.columns.values)
#sys.exit(1)
#print len(df)
#okay, so 1367 OTUs in entire data set, lets trim this down to only run 3, as that one is labeled here with biomock
keepers = ['m4A-301-1', 'm4A-301-2', 'm4A-500-1', 'm4A-500-2', 'm4A-712-1', 'm4A-712-2', 'm4A-736-1', 
           'm4A-736-2', 'm4A-744-1', 'm4A-744-2', 'm4A-755-1', 'm4A-755-2', 'm4A-757-1', 'm4A-757-2', 
           'm4A-766-1', 'm4A-766-2', 'm4A-mock3-16000', 'm4A-mock3-32000a', 'm4A-mock3-32000b', 'm4A-stds']
mock_samples = ['m4A-mock3-16000', 'm4A-mock3-32000a', 'm4A-mock3-32000b', 'm4A-stds']
samples = [item for item in keepers if item not in mock_samples]
#print samples
df2 = df.reindex(columns=keepers, index=natsorted(df.index))

#now drop OTUs where they are all zero
df3 = df2.loc[(df2 != 0).any(1)]
mock_otus = []
for x in df3.index:
    if x.startswith('mock'):
        if not x.startswith('mock3'): #mock3 is actually in some of the samples so can't use for index-bleed measurment
            mock_otus.append(x)
#now slice into two tables containing only mocks and calculate index-bleed
bleed_counts = df3.reindex(columns=samples, index=mock_otus)
bleed_sum = bleed_counts.values.sum()
real_counts = df3.reindex(columns=mock_samples, index=mock_otus)
real_sum = real_counts.values.sum()
index_bleed = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed out of mock: %f%% (%i out of %i)" % (index_bleed, bleed_sum, real_sum)

#now try to to do the opposite, count number of times that samples move into mock
#first generate list of mock otus
sample_otus = []
for x in df3.index:
    if not x.startswith('mock'):
        sample_otus.append(x)
#slice first to samples, further trim list of only things found in mocks, would be spurious or chimeras
sampledf = df3.reindex(columns=samples, index=sample_otus)
sampledf = sampledf.loc[(sampledf != 0).any(1)]
cleaned_otus = sampledf.index
#print len(cleaned_otus), len(sample_otus)

#now using new list grab counts in mock
bleed_counts = df3.reindex(columns=mock_samples, index=cleaned_otus)
bleed_counts = bleed_counts.loc[(bleed_counts != 0).any(1)]
bleed_sum = bleed_counts.values.sum()
#print len(bleed_counts.index), bleed_sum

#finally go back to samples and get read counts for the ovlerlapping otus
real_counts = df3.reindex(columns=samples, index=bleed_counts.index)
real_sum = real_counts.values.sum()
index_bleed2 = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed into mock: %f%% (%i out of %i)" % (index_bleed2, bleed_sum, real_sum)
print "Total index-bleed: %f%%" % (index_bleed + index_bleed2)
# Out:
# Index-bleed out of mock: 0.253212% (2436 out of 962041)
# Index-bleed into mock: 0.015920% (434 out of 2726206)
# Total index-bleed: 0.269131%

# %%
#need to measure index bleed of miseq data now, trying 0 mismatch miseqC dataset first
import pandas as pd
import numpy as np
from natsort import natsorted
import sys
#now load sorted "raw" OTU table into dataframe
df = pd.read_csv('miseq.final.txt', sep='\t', index_col=0)
#print list(df.columns.values)
#sys.exit(1)
#print len(df)
#okay, so 1367 OTUs in entire data set, lets trim this down to only run 3, as that one is labeled here with biomock
keepers = ['m4C-301-1', 'm4C-301-2', 'm4C-500-1', 'm4C-500-2', 'm4C-712-1', 'm4C-712-2', 
           'm4C-736-1', 'm4C-736-2', 'm4C-744-1', 'm4C-744-2', 'm4C-755-1', 'm4C-755-2', 
           'm4C-757-1', 'm4C-757-2', 'm4C-766-1', 'm4C-766-2', 
           'm4C-mock3-16000', 'm4C-mock3-32000a', 'm4C-mock3-32000b', 'm4C-stds']
mock_samples = ['m4C-mock3-16000', 'm4C-mock3-32000a', 'm4C-mock3-32000b', 'm4C-stds']
samples = [item for item in keepers if item not in mock_samples]
#print samples
df2 = df.reindex(columns=keepers, index=natsorted(df.index))

#now drop OTUs where they are all zero
df3 = df2.loc[(df2 != 0).any(1)]
mock_otus = []
for x in df3.index:
    if x.startswith('mock'):
        if not x.startswith('mock3'): #mock3 is actually in some of the samples so can't use for index-bleed measurment
            mock_otus.append(x)
#now slice into two tables containing only mocks and calculate index-bleed
bleed_counts = df3.reindex(columns=samples, index=mock_otus)
bleed_sum = bleed_counts.values.sum()
real_counts = df3.reindex(columns=mock_samples, index=mock_otus)
real_sum = real_counts.values.sum()
index_bleed = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed out of mock: %f%% (%i out of %i)" % (index_bleed, bleed_sum, real_sum)

#now try to to do the opposite, count number of times that samples move into mock
#first generate list of mock otus
sample_otus = []
for x in df3.index:
    if not x.startswith('mock'):
        sample_otus.append(x)
#slice first to samples, further trim list of only things found in mocks, would be spurious or chimeras
sampledf = df3.reindex(columns=samples, index=sample_otus)
sampledf = sampledf.loc[(sampledf != 0).any(1)]
cleaned_otus = sampledf.index
#print len(cleaned_otus), len(sample_otus)

#now using new list grab counts in mock
bleed_counts = df3.reindex(columns=mock_samples, index=cleaned_otus)
bleed_counts = bleed_counts.loc[(bleed_counts != 0).any(1)]
bleed_sum = bleed_counts.values.sum()
#print len(bleed_counts.index), bleed_sum

#finally go back to samples and get read counts for the ovlerlapping otus
real_counts = df3.reindex(columns=samples, index=bleed_counts.index)
real_sum = real_counts.values.sum()
index_bleed2 = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed into mock: %f%% (%i out of %i)" % (index_bleed2, bleed_sum, real_sum)
print "Total index-bleed: %f%%" % (index_bleed + index_bleed2)
# Out:
# Index-bleed out of mock: 0.223127% (1889 out of 846602)
# Index-bleed into mock: 0.012798% (329 out of 2570715)
# Total index-bleed: 0.235925%

# %%
#need to measure index bleed of miseqB dataset, this one slightly differnt as can only measure index out of mock
import pandas as pd
import numpy as np
from natsort import natsorted
import sys
#now load sorted "raw" OTU table into dataframe
df = pd.read_csv('miseq.final.txt', sep='\t', index_col=0)
#print list(df.columns.values)
#sys.exit(1)
#print len(df)
#okay, so 1367 OTUs in entire data set, lets trim this down to only run 3, as that one is labeled here with biomock
keepers = ['m4b-744-1', 'm4b-744-2', 'm4b-766-1', 'm4b-766-2']
mock_samples = ['m4C-mock3-16000', 'm4C-mock3-32000a', 'm4C-mock3-32000b', 'm4C-stds']
samples = [item for item in keepers if item not in mock_samples]
#print samples
df2 = df.reindex(columns=keepers, index=natsorted(df.index))

#now drop OTUs where they are all zero
df3 = df2.loc[(df2 != 0).any(1)]
mock_otus = []
for x in df3.index: #get index from total table
    if x.startswith('mock'):
        if not x.startswith('mock3'): #mock3 is actually in some of the samples so can't use for index-bleed measurment
            mock_otus.append(x)
if len(mock_otus) < 1: #this means that no read counts from mock members were found, so index-bleed is 0
    print "Index-bleed out of mock: 0.0%"
    sys.exit(1)
#now slice into two tables containing only mocks and calculate index-bleed
bleed_counts = df3.reindex(columns=samples, index=mock_otus)
bleed_sum = bleed_counts.values.sum()
real_counts = df3.reindex(columns=mock_samples, index=mock_otus)
real_sum = real_counts.values.sum()
index_bleed = int(bleed_sum) / float(real_sum) * 100
print "Index-bleed out of mock: %f%% (%i out of %i)" % (index_bleed, bleed_sum, real_sum)
# Out:
# Index-bleed out of mock: 0.0%%
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
#while I calculated index bleed from scripts above, create simplier solution for graphing the data by simply
#mapping the reads to the mock community members
# !amptk select -i all.reads.fq -o figure2.reads.demux.fa --format fasta -f figure2.samples.txt
# Out:
# Kept 6452482 reads out of 17459832 total reads

# %%
#now map to mock3.fa
# !vsearch --usearch_global figure2.reads.demux.fa --db $HOME/amptk/DB/amptk_mock3.fa --id 0.97 --strand plus --otutabout fig2.otu_table.txt
# Out:
# vsearch v2.4.2_osx_x86_64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file /Users/jon/amptk/DB/amptk_mock3.fa 100%
# 13072 nt in 23 seqs, min 335, max 680, avg 568
# Masking 100%
# Counting unique k-mers 100%
# Creating index of unique k-mers 100%
# Searching 100%
# Matching query sequences: 2434153 of 6452482 (37.72%)
# Writing OTU table (classic) 100%

# %%
#reorder OTU table and draw heatmap
# !amptk filter -i fig2.otu_table.txt -f $HOME/amptk/DB/amptk_mock3.fa -p 0 --col_order m3-stds,m3-mock3-16000,m3-mock3-3200a,m3-mock3-32000b,m3-744-1,m3-744-2,m3-766-1,m3-766-2,m4A-stds,m4A-mock3-16000,m4A-mock3-32000a,m4A-mock3-32000b,m4A-744-1,m4A-744-2,m4A-766-1,m4A-766-2,m4b-744-1,m4b-744-2,m4b-766-1,m4b-766-2,m4C-stds,m4C-mock3-16000,m4C-mock3-32000a,m4C-mock3-32000b,m4C-744-1,m4C-744-2,m4C-766-1,m4C-766-2
# Out:
# -------------------------------------------------------
# [07:15:34 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [07:15:34 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [07:15:34 PM]: Loading OTU table: fig2.otu_table.txt
# [07:15:34 PM]: OTU table contains 23 OTUs
# [07:15:34 PM]: Sorting OTU table by user defined order (--col_order)
# [07:15:34 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [07:15:34 PM]: Normalizing OTU table to number of reads per sample
# [07:15:34 PM]: Overwriting auto detect index-bleed, setting to 0.000000%
# [07:15:34 PM]: Filtering OTU table down to 23 OTUs
# [07:15:34 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# OTU Table Stats:      fig2.stats.txt
# Sorted OTU table:     fig2.sorted.txt
# Normalized/filter:    fig2.normalized.txt
# ...

# %%
#map the miseq reads to the mock community fasta file
# !vsearch --fastq_filter miseq.fq --fastaout miseq.fa
# !vsearch --usearch_global miseq.fa --id 0.97 --db /Users/jon/amptk/DB/amptk_mock2.fa --otutabout miseq.mock.otu_table.txt
# !rm miseq.fa
# Out:
# vsearch v2.4.2_osx_x86_64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading input file 100%
# 18273964 sequences kept (of which 0 truncated), 0 sequences discarded.
# vsearch v2.4.2_osx_x86_64, 16.0GB RAM, 8 cores
# https://github.com/torognes/vsearch
#
# Reading file /Users/jon/amptk/DB/amptk_mock2.fa 100%
# 14847 nt in 26 seqs, min 335, max 680, avg 571
# Masking 100%
# Counting unique k-mers 100%
# Creating index of unique k-mers 100%
# Searching 100%
# Matching query sequences: 3182927 of 18273964 (17.42%)
# Writing OTU table (classic) 100%

# %%
# !amptk heatmap -i fig2.final.txt -o fig2.svg -m heatmap --color YlOrRd -d tsv --annotate

# %%
import pandas as pd
from natsort import natsorted
#load the miseq table, no filtering version
df = pd.read_csv('miseq.sorted.txt', sep='\t', index_col=0)
#Figure 2 should be about index bleed, so generate a table containing the samples that were run in all runs
figureTwo = ['m4A-stds','m4A-mock3-16000','m4A-mock3-32000a','m4A-mock3-32000b','m4A-744-1','m4A-744-2',
             'm4A-766-1','m4A-766-2','m4A-755-1','m4A-755-2','m4b-744-1','m4b-744-2','m4b-766-1','m4b-766-2' ]
df2 = df.reindex(columns=figureTwo, index=natsorted(df.index))
mocks = []
for x in df2.index:
    if x.startswith('mock'):
        mocks.append(x)
otus = [item for item in df2.index if item not in mocks]

df3 = df2.reindex(columns=figureTwo, index=mocks)
df3.to_csv('figure2.onlymocks.txt', sep='\t')
df4 = df2.reindex(columns=figureTwo, index=otus)
#get number of OTUs from df4 as well as total reads
reads = df4.sum(axis=0)
reads.name ="Other OTUs"
otu_count = df4[df4 > 0].count(axis=0, numeric_only=True)
otu_count.name = "Number of OTUs"
#print reads
print otu_count
#now append the read numbers to df3 dataframe
df3 = df3.append(reads)
print df3
total_reads = df3.sum(axis=0)
print total_reads
df3.to_csv('figure2.miseqAB_only2.txt', sep='\t')


# !amptk heatmap -i figure2.miseqAB_only2.txt -d tsv -o figure2-2.pdf --format pdf -m heatmap --annotate --color YlOrBr --vmax 30000
# Out:
# m4A-stds             34
# m4A-mock3-16000      16
# m4A-mock3-32000a     28
# m4A-mock3-32000b     34
# m4A-744-1           272
# m4A-744-2           354
# m4A-766-1           423
# m4A-766-2           263
# m4A-755-1           361
# m4A-755-2           340
# m4b-744-1           234
# m4b-744-2           315
# m4b-766-1           342
# m4b-766-2           220
# Name: Number of OTUs, dtype: int64
#                                                     m4A-stds  m4A-mock3-16000  \
# #OTU ID
# mock1 |FP170182|Phialocephala fusca_pident=99.6...      8655              727
# mock2 |RF10JR|unknown Ascomycete_pident=100.0_O...      9175            20768
# mock3 |FP170134|Phialocephala lagerbergii_piden...      8652            28520
# mock4 |FP170235|unknown Ascomycete_pident=100.0...      9051            27726
# mock5 |RF1JR|Aspergillus candidus_pident=100.0_...      9054              148
# mock6 |RF3JR|Bjerkandara adusta_pident=100.0_OTU22     13625            13119
# ...

# %%
#now split OTU table into the different parts/segments needed for different figures
#lets do this in python/pandas
import pandas as pd
from natsort import natsorted

#now load OTU table into dataframe
df = pd.read_csv('miseq.mock.otu_table.txt', sep='\t', index_col=0)
print df.columns.values
#headers for 
figureOne = ['m3-stds','m3-mock3-16000','m3-mock3-3200a','m3-mock3-32000b',
             'm4A-stds','m4A-mock3-16000','m4A-mock3-32000a','m4A-mock3-32000b',
             'm4C-stds','m4C-mock3-16000','m4C-mock3-32000a','m4C-mock3-32000b']
#
# Out:
# ['m4A-301-1' 'm4A-301-2' 'm4A-500-1' 'm4A-500-2' 'm4A-712-1' 'm4A-712-2'
#  'm4A-736-1' 'm4A-736-2' 'm4A-744-1' 'm4A-744-2' 'm4A-755-1' 'm4A-755-2'
#  'm4A-757-1' 'm4A-757-2' 'm4A-766-1' 'm4A-766-2' 'm4A-mock3-16000'
#  'm4A-mock3-32000a' 'm4A-mock3-32000b' 'm4A-stds' 'm4C-301-1' 'm4C-301-2'
#  'm4C-500-1' 'm4C-500-2' 'm4C-712-1' 'm4C-712-2' 'm4C-736-1' 'm4C-736-2'
#  'm4C-744-1' 'm4C-744-2' 'm4C-755-2' 'm4C-757-1' 'm4C-757-2' 'm4C-766-1'
#  'm4C-766-2' 'm4C-mock3-16000' 'm4C-mock3-32000a' 'm4C-mock3-32000b'
#  'm4C-stds' 'm4a-1mm-301-1' 'm4a-1mm-301-2' 'm4a-1mm-500-1' 'm4a-1mm-500-2'
#  'm4a-1mm-712-1' 'm4a-1mm-712-2' 'm4a-1mm-736-1' 'm4a-1mm-736-2'
#  'm4a-1mm-744-1' 'm4a-1mm-744-2' 'm4a-1mm-755-1' 'm4a-1mm-755-2'
#  'm4a-1mm-757-1' 'm4a-1mm-757-2' 'm4a-1mm-766-1' 'm4a-1mm-766-2'
#  'm4a-1mm-mock3-16000' 'm4a-1mm-mock3-32000a' 'm4a-1mm-mock3-32000b'
#  'm4a-1mm-stds' 'm4b-744-1' 'm4b-744-2' 'm4b-766-1' 'm4b-766-2']

# %%
#okay, now OTU table in dataframe and files have been renamed according to mock members
#first figure is to compare the stds to the mock communities, set indexes in list and pull from dataframe
print list(df.columns.values)
from natsort import natsorted
figureOne = ['m3-stds','m3-mock3-16000','m3-mock3-3200a','m3-mock3-32000b',
             'm4A-stds','m4A-mock3-16000','m4A-mock3-32000a','m4A-mock3-32000b',
             'm4C-stds','m4C-mock3-16000','m4C-mock3-32000a','m4C-mock3-32000b']
mocks = []
synmocks = []
for k,v in annotation.items():
    if not v in mocks:
        if v.startswith('mock'):
            mocks.append(v)
        else:
            synmocks.append(v)
fig1 = df.reindex(columns=figureOne, index=natsorted(mocks))
#print fig1
#write to file
fig1.to_csv('synmock.figure1.abundances.txt', sep='\t')
#then generate heatmap
# !amptk heatmap -i synmock.figure1.abundances.txt -d tsv -o figure1.pdf -m heatmap --annotate --color YlOrRd
# Out:
# ['m3-755-2', 'm3-301-1', 'm3-301-2', 'm3-500-1', 'm3-500-2', 'm3-712-1', 'm3-712-2', 'm3-736-1', 'm3-736-2', 'm3-744-1', 'm3-744-2', 'm3-755-1', 'm3-757-2', 'm3-766-1', 'm3-766-2', 'm3-mock3-16000', 'm3-mock3-32000b', 'm3-mock3-3200a', 'm3-stds', 'm4A-301-1', 'm4A-301-2', 'm4A-500-1', 'm4A-500-2', 'm4A-712-1', 'm4A-712-2', 'm4A-736-1', 'm4A-736-2', 'm4A-744-1', 'm4A-744-2', 'm4A-755-1', 'm4A-755-2', 'm4A-757-1', 'm4A-757-2', 'm4A-766-1', 'm4A-766-2', 'm4A-mock3-16000', 'm4A-mock3-32000a', 'm4A-mock3-32000b', 'm4A-stds', 'm4C-301-1', 'm4C-301-2', 'm4C-500-1', 'm4C-500-2', 'm4C-712-1', 'm4C-712-2', 'm4C-736-1', 'm4C-736-2', 'm4C-744-1', 'm4C-744-2', 'm4C-755-1', 'm4C-755-2', 'm4C-757-1', 'm4C-757-2', 'm4C-766-1', 'm4C-766-2', 'm4C-mock3-16000', 'm4C-mock3-32000a', 'm4C-mock3-32000b', 'm4C-stds', 'm4b-744-1', 'm4b-744-2', 'm4b-766-1', 'm4b-766-2', 'm5-301-1', 'm5-301-2', 'm5-500-1', 'm5-500-2', 'm5-712-1', 'm5-712-2', 'm5-736-1', 'm5-736-2', 'm5-744-1', 'm5-744-2', 'm5-755-1', 'm5-755-2
# ...

# %%
#try to create normalized figure
# !amptk heatmap -i synmock.figure1.abundances.expected.txt --debug -d tsv -o figure1.normal.pdf --normalize otudb.stats.txt -m heatmap --color YlOrRd
# Out:
#          stds-expected  m3-stds  m3-mock3-16000  m3-mock3-3200a  \
# #OTU ID
# mock1             1000     4705              19               6
# mock2             1000     4732           11241           10358
# mock3             1000     4532           12930           11600
# mock4             1000     3941           14526           12488
# mock5             1000     2679              31              23
# mock6             1000     3801            7925            6978
# mock7             1000     3138            7573            6283
# mock8             1000     3573            7390            7075
# mock9             1000     3861            8703           10196
# mock10            1000     3328            3923            4075
# mock11            1000     3730              90             111
# mock12            1000     3782            6738            6816
# mock13            1000     3583            2946            2879
# ...

# %% [markdown]
# <img src="figure1.pdf">

# %%
#Figure 2 should be about index bleed, so generate a table containing the samples that were run in all runs
figureTwo = ['m3-stds','m3-mock3-16000','m3-744-1','m3-744-2','m3-766-1','m3-766-2',
             'm4A-stds','m4A-mock3-16000','m4A-744-1','m4A-744-2','m4A-766-1','m4A-766-2',
             'm4b-744-1','m4b-744-2','m4b-766-1','m4b-766-2',
             'm4C-stds','m4C-mock3-16000','m4C-744-1','m4C-744-2','m4C-766-1','m4C-766-2']
#only has the mock OTUs
fig2 = df.reindex(columns=figureTwo, index=natsorted(mocks))
fig2.to_csv('synmock.figure2.index-bleed.txt', sep='\t')
#has all OTUs, dropping those that are not found in any of these samples
fig2b = df.reindex(columns=figureTwo)
fig2b = fig2b.loc[~(fig2b==0).all(axis=1)]
fig2BB = fig2b.reindex(index=natsorted(fig2b.index))
fig2BB.to_csv('synmock.figure2b.index-bleed.txt', sep='\t')
# !amptk heatmap -i synmock.figure2.index-bleed.txt -d tsv -o figure2.pdf -m heatmap --annotate --color BuPu

# %% [markdown]
# <img src="figure2.pdf">

# %%
#now slice the OTU table for each of the runs, Ion3, Miseq4A, Miseq4C, Ion5
#load original table, not the name changed version for normal processing
df2 = pd.read_csv('otudb.otu_table.txt', sep='\t')
df2.set_index(OTUhead, inplace=True)
ion3 = ['m3-301-1', 'm3-301-2', 'm3-500-1', 'm3-500-2', 'm3-712-1', 'm3-712-2', 
        'm3-736-1', 'm3-736-2', 'm3-744-1', 'm3-744-2', 'm3-755-1', 'm3-755-2',
        'm3-757-2', 'm3-766-1', 'm3-766-2', 'm3-mock3-16000']
ion3df = df2.reindex(columns=ion3, index=natsorted(df2.index))
ion3df.to_csv('ion3.otu_table.txt', sep='\t')
miseq4a = ['m4A-301-1', 'm4A-301-2', 'm4A-500-1', 'm4A-500-2', 'm4A-712-1', 
           'm4A-712-2', 'm4A-736-1', 'm4A-736-2', 'm4A-744-1', 'm4A-744-2', 
           'm4A-755-1', 'm4A-755-2', 'm4A-757-1', 'm4A-757-2', 'm4A-766-1', 'm4A-766-2', 'm4A-mock3-16000']
miseq4adf = df2.reindex(columns=miseq4a, index=natsorted(df2.index))
miseq4adf.to_csv('miseq4a.otu_table.txt', sep='\t')
miseq4c = ['m4C-301-1', 'm4C-301-2', 'm4C-500-1', 'm4C-500-2', 'm4C-712-1', 
           'm4C-712-2', 'm4C-736-1', 'm4C-736-2', 'm4C-744-1', 'm4C-744-2', 
           'm4C-755-1', 'm4C-755-2', 'm4C-757-1', 'm4C-757-2', 'm4C-766-1', 'm4C-766-2', 'm4C-mock3-16000']
miseq4cdf = df2.reindex(columns=miseq4c, index=natsorted(df2.index))
miseq4cdf.to_csv('miseq4c.otu_table.txt', sep='\t')
ion5 = ['m5-301-1', 'm5-301-2', 'm5-500-1', 'm5-500-2', 'm5-712-1', 
        'm5-712-2', 'm5-736-1', 'm5-736-2', 'm5-744-1', 'm5-744-2', 
        'm5-755-1', 'm5-755-2', 'm5-757-1', 'm5-757-2', 'm5-766-1', 'm5-766-2', 'm5-SynMock2-8000']
ion5df = df2.reindex(columns=ion5, index=natsorted(df2.index))
ion5df.to_csv('ion5.otu_table.txt', sep='\t')

# %%
#now run filtering on these data
# !amptk filter -i ion3.otu_table.txt -f otudb.cluster.otus.fa -o ion3 -b m3-mock3-16000 -m mock3 -c in -s auto
# Out:
# -------------------------------------------------------
# [09:30:44 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [09:30:44 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [09:30:44 PM]: Loading OTU table: ion3.otu_table.txt
# [09:30:44 PM]: OTU table contains 2473 OTUs
# [09:30:44 PM]: Mapping OTUs to Mock Community (USEARCH)
# [09:30:45 PM]: Sorting OTU table naturally
# [09:30:45 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [09:30:45 PM]: Normalizing OTU table to number of reads per sample
# [09:30:45 PM]: Index bleed, samples into mock: 0.067999%.
# [09:30:45 PM]: Will use value of 0.100000% for index-bleed OTU filtering.
# [09:30:45 PM]: Auto subtract filter set to 26
# [09:30:45 PM]: Subtracting 26 from OTU table
# [09:30:45 PM]: Filtering OTU table down to 397 OTUs
# [09:30:45 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# ...

# %%
#get biom of unfiltered data
#first trim sorted OTU table, will remove last column which is mock
#!gsed -r 's/\s+\S+$//' ion3.sorted.txt > ion3.sorted.nomock.txt

import pandas as pd
from natsort import natsorted
#pull out header for indexing later
with open('ion3.sorted.txt', 'rU') as f:
    first_line = f.readline()
    OTUhead = first_line.split('\t')[0]
    
#now load sorted "raw" OTU table into dataframe
ion3sorted = pd.read_csv('ion3.sorted.txt', sep='\t')
ion3sorted.set_index(OTUhead, inplace=True)

#now we want to drop last column
ion3 = ['m3-301-1', 'm3-301-2', 'm3-500-1', 'm3-500-2', 'm3-712-1', 'm3-712-2', 
        'm3-736-1', 'm3-736-2', 'm3-744-1', 'm3-744-2', 'm3-755-1', 'm3-755-2',
        'm3-757-2', 'm3-766-1', 'm3-766-2']
ion3cleaned = ion3sorted.reindex(columns=ion3, index=natsorted(ion3sorted.index))

#now drop OTUs where they are all zero
fs = ion3cleaned.sum(axis=0)
filtered = pd.DataFrame(ion3cleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(ion3sorted), len(ion3sorted.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv('ion3.sorted.nomock.txt', sep='\t')

#now convert to biom
# !amptk taxonomy -f otudb.cluster.otus.fa -o ion3_raw -i ion3.sorted.nomock.txt -d ITS2 -m ion3.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# 2473 16 1654 15
# -------------------------------------------------------
# [01:04:13 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [01:04:14 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [01:04:14 PM]: Loading FASTA Records
# [01:04:14 PM]: 2,480 OTUs
# [01:04:14 PM]: Appending taxonomy to OTU table and OTUs
# [01:04:14 PM]: Generating phylogenetic tree
# [01:04:34 PM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [01:04:34 PM]: Classic OTU table with taxonomy: ion3_raw.otu_table.taxonomy.txt
# [01:04:37 PM]: BIOM OTU table created: ion3_raw.biom
# [01:04:37 PM]: OTUs with taxonomy: ion3_raw.otus.taxonomy.fa
# [01:04:37 PM]: OTU phylogeny: ion3_raw.tree.phy
# -------------------------------------------------------

# %%
#run the phyloseq scripts
# !/Users/jon/amptk/util/phyloseq_graphs.R ion3_raw.biom ion3_raw.tree.phy ion3_raw
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# There were 22 warnings (use warnings() to see them)
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1561485
# Run 1 stress 0.1601276
# Run 2 stress 0.1617538
# Run 3 stress 0.1638083
# Run 4 stress 0.1720631
# Run 5 stress 0.1561485
# ... Procrustes: rmse 0.0002629328  max resid 0.0005522638
# ... Similar to previous best
# Run 6 stress 0.1640377
# Run 7 stress 0.1601277
# Run 8 stress 0.1720647
# Run 9 stress 0.1658563
# Run 10 stress 0.1561486
# ... Procrustes: rmse 0.0004754189  max resid 0.0009814214
# ... Similar to previous best
# Run 11 stress 0.1561483
# ... New best solution
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
#  Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.37159 0.37159  3.1052 0.19281 0.1173
# Residuals                 13   1.55567 0.11967         0.80719
# Total                     14   1.92726                 1.00000
# ```
# ###NMDS using raup
# ![alt text](ion3_raw.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4609 0.46093  1.0299 0.07341 0.4272
# Residuals                 13    5.8178 0.44752         0.92659
# Total                     14    6.2787                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](ion3_raw.Treatment.braycurtis.pdf)

# %%
#get biom of filtered data
# !amptk taxonomy -f ion3.filtered.otus.fa -i ion3.final.txt -d ITS2 -m ion3.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# -------------------------------------------------------
# [09:59:49 AM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [09:59:49 AM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [09:59:49 AM]: Loading FASTA Records
# [09:59:49 AM]: 397 OTUs
# [09:59:49 AM]: Appending taxonomy to OTU table and OTUs
# [09:59:49 AM]: Generating phylogenetic tree
# [09:59:50 AM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [09:59:50 AM]: Classic OTU table with taxonomy: ion3.otu_table.taxonomy.txt
# [09:59:52 AM]: BIOM OTU table created: ion3.biom
# [09:59:52 AM]: OTUs with taxonomy: ion3.otus.taxonomy.fa
# [09:59:52 AM]: OTU phylogeny: ion3.tree.phy
# -------------------------------------------------------

# %%
#run the phyloseq scripts
# !/Users/jon/amptk/util/phyloseq_graphs.R ion3.biom ion3.tree.phy ion3_filtered
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Warning messages:
# 1: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 2: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1824396
# Run 1 stress 0.2047899
# Run 2 stress 0.2014881
# Run 3 stress 0.2057218
# Run 4 stress 0.2025887
# Run 5 stress 0.1824394
# ... New best solution
# ... Procrustes: rmse 0.0003814994  max resid 0.0008967817
# ... Similar to previous best
# Run 6 stress 0.2274207
# Run 7 stress 0.2057195
# Run 8 stress 0.2042308
# Run 9 stress 0.2043601
# Run 10 stress 0.1811953
# ... New best solution
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.45024 0.45024  2.4021 0.15596 0.1156
# Residuals                 13   2.43661 0.18743         0.84404
# Total                     14   2.88685                 1.00000
#
# ```
# ###NMDS using jaccard
# ![alt text](ion3_filtered.Treatment.jaccard.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4617 0.46174  1.0246 0.07306 0.4396
# Residuals                 13    5.8587 0.45067         0.92694
# Total                     14    6.3205                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](ion3_filtered.Treatment.braycurtis.pdf)

# %%
#now run filtering without subtraction
# !amptk filter -i ion3.otu_table.txt -f otudb.cluster.otus.fa -o ion3_nosub -b m3-mock3-16000 -m mock3 -c in
# Out:
# -------------------------------------------------------
# [02:09:11 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:09:11 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:09:11 PM]: Loading OTU table: ion3.otu_table.txt
# [02:09:11 PM]: OTU table contains 2473 OTUs
# [02:09:11 PM]: Mapping OTUs to Mock Community (USEARCH)
# [02:09:11 PM]: Sorting OTU table naturally
# [02:09:11 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [02:09:11 PM]: Normalizing OTU table to number of reads per sample
# [02:09:11 PM]: Index bleed, samples into mock: 0.067999%.
# [02:09:11 PM]: Will use value of 0.100000% for index-bleed OTU filtering.
# [02:09:12 PM]: Filtering OTU table down to 1353 OTUs
# [02:09:12 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# OTU Table Stats:      ion3_nosub.stats.txt
# ...

# %%
#create no subtraction biom file
# !amptk taxonomy -i ion3_nosub.final.txt -f ion3_nosub.filtered.otus.fa -t otudb.cluster.otus.taxonomy.txt -d ITS2 -m ion3.mapping_file.txt
# Out:
# -------------------------------------------------------
# [02:14:03 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:14:03 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:14:03 PM]: Loading FASTA Records
# [02:14:03 PM]: 1,353 OTUs
# [02:14:03 PM]: Appending taxonomy to OTU table and OTUs
# [02:14:03 PM]: Generating phylogenetic tree
# [02:14:07 PM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [02:14:07 PM]: Classic OTU table with taxonomy: ion3_nosub.otu_table.taxonomy.txt
# [02:14:08 PM]: BIOM OTU table created: ion3_nosub.biom
# [02:14:08 PM]: OTUs with taxonomy: ion3_nosub.otus.taxonomy.fa
# [02:14:08 PM]: OTU phylogeny: ion3_nosub.tree.phy
# -------------------------------------------------------

# %%
#run the phyloseq scripts
# !/Users/jon/amptk/util/phyloseq_graphs.R ion3_nosub.biom ion3_nosub.tree.phy ion3_nosub
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Warning messages:
# 1: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 2: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 3: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 4: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 5: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 6: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1442957
# Run 1 stress 0.1816228
# Run 2 stress 0.1442957
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.40146 0.40146  3.0324 0.18914 0.1058
# Residuals                 13   1.72107 0.13239         0.81086
# Total                     14   2.12252                 1.00000
# ```
# ###NMDS using Raup
# ![alt text](ion3_nosub.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4601 0.46011  1.0269 0.07321 0.4411
# Residuals                 13    5.8249 0.44807         0.92679
# Total                     14    6.2850                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](ion3_nosub.Treatment.braycurtis.pdf)

# %%
#now run MiseqA dataset, first filter
# !amptk filter -i miseq4a.otu_table.txt -f otudb.cluster.otus.fa -o miseq4a -b m4A-mock3-16000 -m mock3 -c in -s auto
# Out:
# -------------------------------------------------------
# [10:03:37 AM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [10:03:37 AM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [10:03:37 AM]: Loading OTU table: miseq4a.otu_table.txt
# [10:03:37 AM]: OTU table contains 2473 OTUs
# [10:03:37 AM]: Mapping OTUs to Mock Community (USEARCH)
# [10:03:38 AM]: Sorting OTU table naturally
# [10:03:38 AM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [10:03:38 AM]: Normalizing OTU table to number of reads per sample
# [10:03:38 AM]: Index bleed, samples into mock: 0.054002%.
# [10:03:38 AM]: Will use value of 0.100000% for index-bleed OTU filtering.
# [10:03:38 AM]: Auto subtract filter set to 25
# [10:03:38 AM]: Subtracting 25 from OTU table
# [10:03:38 AM]: Filtering OTU table down to 446 OTUs
# [10:03:38 AM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# ...

# %%
import pandas as pd
from natsort import natsorted
#pull out header for indexing later
with open('miseq4a.sorted.txt', 'rU') as f:
    first_line = f.readline()
    OTUhead = first_line.split('\t')[0]
    
#now load sorted "raw" OTU table into dataframe
dfsorted = pd.read_csv('miseq4a.sorted.txt', sep='\t')
dfsorted.set_index(OTUhead, inplace=True)

#now we want to drop last column
header = ['m4A-301-1', 'm4A-301-2', 'm4A-500-1', 'm4A-500-2', 'm4A-712-1', 
           'm4A-712-2', 'm4A-736-1', 'm4A-736-2', 'm4A-744-1', 'm4A-744-2', 
           'm4A-755-1', 'm4A-755-2', 'm4A-757-1', 'm4A-757-2', 'm4A-766-1', 'm4A-766-2']
dfcleaned = dfsorted.reindex(columns=header, index=natsorted(dfsorted.index))

#now drop OTUs where they are all zero
fs = dfcleaned.sum(axis=0)
filtered = pd.DataFrame(dfcleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(dfsorted), len(dfsorted.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv('miseq4a.sorted.nomock.txt', sep='\t')

#now convert to biom
# !amptk taxonomy -f otudb.cluster.otus.fa -o miseq4a_raw -i miseq4a.sorted.nomock.txt -d ITS2 -m m4a.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# 2473 17 2179 16
# -------------------------------------------------------
# [01:13:44 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [01:13:45 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [01:13:45 PM]: Loading FASTA Records
# [01:13:45 PM]: 2,480 OTUs
# [01:13:45 PM]: Appending taxonomy to OTU table and OTUs
# [01:13:45 PM]: Generating phylogenetic tree
# [01:13:56 PM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [01:13:56 PM]: Classic OTU table with taxonomy: miseq4a_raw.otu_table.taxonomy.txt
# [01:13:58 PM]: BIOM OTU table created: miseq4a_raw.biom
# [01:13:58 PM]: OTUs with taxonomy: miseq4a_raw.otus.taxonomy.fa
# [01:13:58 PM]: OTU phylogeny: miseq4a_raw.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq
# !/Users/jon/amptk/util/phyloseq_graphs.R miseq4a_raw.biom miseq4a_raw.tree.phy m4a_raw
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# There were 27 warnings (use warnings() to see them)
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1571083
# Run 1 stress 0.1506067
# ... New best solution
# ... Procrustes: rmse 0.1073115  max resid 0.3556422
# Run 2 stress 0.1544389
# Run 3 stress 0.1581899
# Run 4 stress 0.1544389
# Run 5 stress 0.154439
# Run 6 stress 0.1506066
# ... New best solution
# ... Procrustes: rmse 2.99924e-05  max resid 6.735118e-05
# ... Similar to previous best
# Run 7 stress 0.154439
# Run 8 stress 0.1571084
# Run 9 stress 0.1581898
# Run 10 stress 0.1715844
# Run 11 stress 0.1502516
# ... New best solution
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.30725 0.307245  4.0315 0.22358 0.1106
# Residuals                 14   1.06697 0.076212         0.77642
# Total                     15   1.37421                  1.00000
# ```
# ###NMDS using Raup
# ![alt text](m4a_raw.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4526 0.45255   1.016 0.06766 0.4572
# Residuals                 14    6.2357 0.44541         0.93234
# Total                     15    6.6882                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](m4a_raw.Treatment.braycurtis.pdf)

# %%
#get biom of filtered data
# !amptk taxonomy -f miseq4a.filtered.otus.fa -i miseq4a.final.txt -d ITS2 -m m4a.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# -------------------------------------------------------
# [10:08:28 AM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [10:08:29 AM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [10:08:29 AM]: Loading FASTA Records
# [10:08:29 AM]: 446 OTUs
# [10:08:29 AM]: Appending taxonomy to OTU table and OTUs
# [10:08:29 AM]: Generating phylogenetic tree
# [10:08:30 AM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [10:08:30 AM]: Classic OTU table with taxonomy: miseq4a.otu_table.taxonomy.txt
# [10:08:31 AM]: BIOM OTU table created: miseq4a.biom
# [10:08:31 AM]: OTUs with taxonomy: miseq4a.otus.taxonomy.fa
# [10:08:31 AM]: OTU phylogeny: miseq4a.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq
# !/Users/jon/amptk/util/phyloseq_graphs.R miseq4a.biom miseq4a.tree.phy miseq4a_filtered
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Warning messages:
# 1: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 2: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 3: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.2111013
# Run 1 stress 0.2124962
# Run 2 stress 0.2458501
# Run 3 stress 0.2244359
# Run 4 stress 0.2076407
# ... New best solution
# ... Procrustes: rmse 0.1588691  max resid 0.3446601
# Run 5 stress 0.2449464
# Run 6 stress 0.2182043
# Run 7 stress 0.2100472
# Run 8 stress 0.2111013
# Run 9 stress 0.2507159
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model     R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.55147 0.55147  3.0899 0.1808 0.0564 .
# Residuals                 14   2.49866 0.17848         0.8192
# Total                     15   3.05013                 1.0000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ```
# ###NMDS using raup
# ![alt text](miseq4a_filtered.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4535 0.45350  1.0097 0.06727  0.466
# Residuals                 14    6.2882 0.44916         0.93273
# Total                     15    6.7417                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](miseq4a_filtered.Treatment.braycurtis.pdf)

# %%
#now run miseqA without subtraction filter
# !amptk filter -i miseq4a.otu_table.txt -f otudb.cluster.otus.fa -o miseq4a_nosub -b m4A-mock3-16000 -m mock3 -c in
# Out:
# -------------------------------------------------------
# [02:19:45 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:19:45 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:19:45 PM]: Loading OTU table: miseq4a.otu_table.txt
# [02:19:45 PM]: OTU table contains 2473 OTUs
# [02:19:45 PM]: Mapping OTUs to Mock Community (USEARCH)
# [02:19:45 PM]: Sorting OTU table naturally
# [02:19:45 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [02:19:45 PM]: Normalizing OTU table to number of reads per sample
# [02:19:45 PM]: Index bleed, samples into mock: 0.054002%.
# [02:19:45 PM]: Will use value of 0.100000% for index-bleed OTU filtering.
# [02:19:46 PM]: Filtering OTU table down to 1912 OTUs
# [02:19:46 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# ...

# %%
#create no subtraction biom file
# !amptk taxonomy -i miseq4a_nosub.final.txt -f miseq4a_nosub.filtered.otus.fa -t otudb.cluster.otus.taxonomy.txt -d ITS2 -m m4a.mapping_file.txt
# Out:
# -------------------------------------------------------
# [02:21:31 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:21:31 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:21:31 PM]: Loading FASTA Records
# [02:21:31 PM]: 1,912 OTUs
# [02:21:31 PM]: Appending taxonomy to OTU table and OTUs
# [02:21:31 PM]: Generating phylogenetic tree
# [02:21:38 PM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [02:21:38 PM]: Classic OTU table with taxonomy: miseq4a_nosub.otu_table.taxonomy.txt
# [02:21:40 PM]: BIOM OTU table created: miseq4a_nosub.biom
# [02:21:40 PM]: OTUs with taxonomy: miseq4a_nosub.otus.taxonomy.fa
# [02:21:40 PM]: OTU phylogeny: miseq4a_nosub.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq
# !/Users/jon/amptk/util/phyloseq_graphs.R miseq4a_nosub.biom miseq4a_nosub.tree.phy miseq4a_nosub
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# There were 27 warnings (use warnings() to see them)
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1539122
# Run 1 stress 0.1623708
# Run 2 stress 0.1633079
# Run 3 stress 0.2182797
# Run 4 stress 0.1767905
# Run 5 stress 0.1623708
# Run 6 stress 0.162914
# Run 7 stress 0.1539122
# ... Procrustes: rmse 9.288234e-06  max resid 2.484461e-05
# ... Similar to previous best
# Run 8 stress 0.163308
# Run 9 stress 0.1767905
# Run 10 stress 0.1642
# Run 11 stress 0.1539122
# ... Procrustes: rmse 9.123212e-06  max resid 2.105123e-05
# ... Similar to previous best
# Run 12 stress 0.1539122
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.46981 0.46981  4.4274 0.24026 0.0667 .
# Residuals                 14   1.48560 0.10611         0.75974
# Total                     15   1.95540                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###NMDS using raup
# ![alt text](miseq4a_nosub.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4522 0.45220  1.0131 0.06748 0.4511
# Residuals                 14    6.2486 0.44633         0.93252
# Total                     15    6.7008                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](miseq4a_nosub.Treatment.braycurtis.pdf)

# %%
#now process miSeqC dataset
# !amptk filter -i miseq4c.otu_table.txt -f otudb.cluster.otus.fa -o miseq4c -b m4C-mock3-16000 -m mock3 -c in -s auto
# Out:
# -------------------------------------------------------
# [10:10:58 AM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [10:10:58 AM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [10:10:58 AM]: Loading OTU table: miseq4c.otu_table.txt
# [10:10:58 AM]: OTU table contains 2473 OTUs
# [10:10:58 AM]: Mapping OTUs to Mock Community (USEARCH)
# [10:10:58 AM]: Sorting OTU table naturally
# [10:10:58 AM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [10:10:58 AM]: Normalizing OTU table to number of reads per sample
# [10:10:58 AM]: Index bleed, samples into mock: 0.051003%.
# [10:10:58 AM]: Will use value of 0.100000% for index-bleed OTU filtering.
# [10:10:58 AM]: Auto subtract filter set to 17
# [10:10:58 AM]: Subtracting 17 from OTU table
# [10:10:59 AM]: Filtering OTU table down to 502 OTUs
# [10:10:59 AM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# ...

# %%
import pandas as pd
from natsort import natsorted
#pull out header for indexing later
with open('miseq4c.sorted.txt', 'rU') as f:
    first_line = f.readline()
    OTUhead = first_line.split('\t')[0]
    
#now load sorted "raw" OTU table into dataframe
dfsorted = pd.read_csv('miseq4c.sorted.txt', sep='\t')
dfsorted.set_index(OTUhead, inplace=True)

#now we want to drop last column
header = ['m4C-301-1', 'm4C-301-2', 'm4C-500-1', 'm4C-500-2', 'm4C-712-1', 
           'm4C-712-2', 'm4C-736-1', 'm4C-736-2', 'm4C-744-1', 'm4C-744-2', 
           'm4C-755-1', 'm4C-755-2', 'm4C-757-1', 'm4C-757-2', 'm4C-766-1', 'm4C-766-2']
dfcleaned = dfsorted.reindex(columns=header, index=natsorted(dfsorted.index))

#now drop OTUs where they are all zero
fs = dfcleaned.sum(axis=0)
filtered = pd.DataFrame(dfcleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(dfsorted), len(dfsorted.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv('miseq4c.sorted.nomock.txt', sep='\t')

#now convert to biom
# !amptk taxonomy -f otudb.cluster.otus.fa -o miseq4c_raw -i miseq4c.sorted.nomock.txt -d ITS2 \
-m m4c.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# 2473 17 2109 16
# -------------------------------------------------------
# [01:19:16 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [01:19:16 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [01:19:16 PM]: Loading FASTA Records
# [01:19:16 PM]: 2,480 OTUs
# [01:19:16 PM]: Appending taxonomy to OTU table and OTUs
# [01:19:17 PM]: Generating phylogenetic tree
# [01:19:28 PM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [01:19:28 PM]: Classic OTU table with taxonomy: miseq4c_raw.otu_table.taxonomy.txt
# [01:19:29 PM]: BIOM OTU table created: miseq4c_raw.biom
# [01:19:29 PM]: OTUs with taxonomy: miseq4c_raw.otus.taxonomy.fa
# [01:19:29 PM]: OTU phylogeny: miseq4c_raw.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq
# !/Users/jon/amptk/util/phyloseq_graphs.R miseq4c_raw.biom miseq4c_raw.tree.phy m4c_raw
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# There were 27 warnings (use warnings() to see them)
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1437543
# Run 1 stress 0.1459038
# Run 2 stress 0.3525223
# Run 3 stress 0.1437543
# ... New best solution
# ... Procrustes: rmse 6.969975e-06  max resid 1.272703e-05
# ... Similar to previous best
# Run 4 stress 0.1495874
# Run 5 stress 0.1503506
# Run 6 stress 0.1459042
# Run 7 stress 0.1437544
# ... Procrustes: rmse 0.0001113067  max resid 0.0002100703
# ... Similar to previous best
# Run 8 stress 0.1537847
# Run 9 stress 0.1459037
# Run 10 stress 0.1692988
# Run 11 stress 0.1437543
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.61753 0.61753  12.067 0.46291 0.0079 **
# Residuals                 14   0.71647 0.05118         0.53709
# Total                     15   1.33400                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###NMDS using jaccard
# ![alt text](m4c_raw.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model     R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4518 0.45180  1.0086 0.0672 0.4753
# Residuals                 14    6.2712 0.44795         0.9328
# Total                     15    6.7230                 1.0000
# ```
# ###NMDS using braycurtis
# ![alt text](m4c_raw.Treatment.braycurtis.pdf)

# %%
#get biom of filtered data
# !amptk taxonomy -f miseq4c.filtered.otus.fa -i miseq4c.final.txt -d ITS2 -m m4c.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# -------------------------------------------------------
# [10:14:31 AM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [10:14:31 AM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [10:14:31 AM]: Loading FASTA Records
# [10:14:31 AM]: 502 OTUs
# [10:14:31 AM]: Appending taxonomy to OTU table and OTUs
# [10:14:32 AM]: Generating phylogenetic tree
# [10:14:33 AM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [10:14:33 AM]: Classic OTU table with taxonomy: miseq4c.otu_table.taxonomy.txt
# [10:14:35 AM]: BIOM OTU table created: miseq4c.biom
# [10:14:35 AM]: OTUs with taxonomy: miseq4c.otus.taxonomy.fa
# [10:14:35 AM]: OTU phylogeny: miseq4c.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq
# !/Users/jon/amptk/util/phyloseq_graphs.R miseq4c.biom miseq4c.tree.phy miseq4c_filtered
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Warning messages:
# 1: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 2: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 3: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# 4: In parseFunction(i$metadata$taxonomy) :
#   Empty taxonomy vector encountered.
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.2089407
# Run 1 stress 0.2230954
# Run 2 stress 0.2172407
# Run 3 stress 0.2230953
# Run 4 stress 0.237226
# Run 5 stress 0.2230954
# Run 6 stress 0.2110097
# Run 7 stress 0.2161311
# Run 8 stress 0.2226551
# Run 9 stress 0.2205502
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.52965 0.52965  3.3617 0.19363 0.0562 .
# Residuals                 14   2.20575 0.15755         0.80637
# Total                     15   2.73540                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ```
# ###NMDS using jaccard
# ![alt text](miseq4c_filtered.Treatment.jaccard.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4521 0.45211  1.0027 0.06683  0.486
# Residuals                 14    6.3125 0.45089         0.93317
# Total                     15    6.7646                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](miseq4c_filtered.Treatment.braycurtis.pdf)

# %%
#generate no subtraction filter
# !amptk filter -i miseq4c.otu_table.txt -f otudb.cluster.otus.fa -o miseq4c_nosub -b m4C-mock3-16000 -m mock3 -c in
# Out:
# -------------------------------------------------------
# [02:25:18 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:25:19 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:25:19 PM]: Loading OTU table: miseq4c.otu_table.txt
# [02:25:19 PM]: OTU table contains 2473 OTUs
# [02:25:19 PM]: Mapping OTUs to Mock Community (USEARCH)
# [02:25:19 PM]: Sorting OTU table naturally
# [02:25:19 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [02:25:19 PM]: Normalizing OTU table to number of reads per sample
# [02:25:19 PM]: Index bleed, samples into mock: 0.051003%.
# [02:25:19 PM]: Will use value of 0.100000% for index-bleed OTU filtering.
# [02:25:20 PM]: Filtering OTU table down to 1809 OTUs
# [02:25:20 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# ...

# %%
#generate biom
# !amptk taxonomy -f miseq4c_nosub.filtered.otus.fa -i miseq4c_nosub.final.txt -d ITS2 \
-m m4c.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# -------------------------------------------------------
# [02:26:28 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:26:28 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:26:28 PM]: Loading FASTA Records
# [02:26:28 PM]: 1,809 OTUs
# [02:26:28 PM]: Appending taxonomy to OTU table and OTUs
# [02:26:28 PM]: Generating phylogenetic tree
# [02:26:34 PM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [02:26:34 PM]: Classic OTU table with taxonomy: miseq4c_nosub.otu_table.taxonomy.txt
# [02:26:35 PM]: BIOM OTU table created: miseq4c_nosub.biom
# [02:26:35 PM]: OTUs with taxonomy: miseq4c_nosub.otus.taxonomy.fa
# [02:26:35 PM]: OTU phylogeny: miseq4c_nosub.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq
# !/Users/jon/amptk/util/phyloseq_graphs.R miseq4c_nosub.biom miseq4c_nosub.tree.phy miseq4c_nosub
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# There were 26 warnings (use warnings() to see them)
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1647859
# Run 1 stress 0.181755
# Run 2 stress 0.1658236
# Run 3 stress 0.1613274
# ... New best solution
# ... Procrustes: rmse 0.06408241  max resid 0.1751406
# Run 4 stress 0.1647859
# Run 5 stress 0.1613273
# ... New best solution
# ... Procrustes: rmse 9.368663e-05  max resid 0.0001859158
# ... Similar to previous best
# Run 6 stress 0.279312
# Run 7 stress 0.1613272
# ... New best solution
# ... Procrustes: rmse 4.893853e-05  max resid 7.774388e-05
# ... Similar to previous best
# Run 8 stress 0.1647859
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.47376 0.47376  4.3466 0.23692 0.0576 .
# Residuals                 14   1.52594 0.10900         0.76308
# Total                     15   1.99970                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###NMDS using raup
# ![alt text](miseq4c_nosub.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4509 0.45092  1.0046 0.06695 0.4769
# Residuals                 14    6.2841 0.44886         0.93305
# Total                     15    6.7350                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](miseq4c_nosub.Treatment.braycurtis.pdf)

# %%
#finally run ion5 data
# !amptk filter -i ion5.otu_table.txt -f otudb.cluster.otus.fa -o ion5 -b m5-SynMock2-8000 -m synmock -s auto
# Out:
# -------------------------------------------------------
# [10:17:07 AM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [10:17:07 AM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [10:17:07 AM]: Loading OTU table: ion5.otu_table.txt
# [10:17:07 AM]: OTU table contains 2473 OTUs
# [10:17:07 AM]: Mapping OTUs to Mock Community (USEARCH)
# [10:17:07 AM]: Sorting OTU table naturally
# [10:17:07 AM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [10:17:07 AM]: Normalizing OTU table to number of reads per sample
# [10:17:07 AM]: Index bleed, mock into samples: 0.174878%.  Index bleed, samples into mock: 0.103002%.
# [10:17:07 AM]: Will use value of 0.200000% for index-bleed OTU filtering.
# [10:17:07 AM]: Auto subtract filter set to 36
# [10:17:07 AM]: Subtracting 36 from OTU table
# [10:17:08 AM]: Filtering OTU table down to 369 OTUs
# [10:17:08 AM]: Filtering valid OTUs
# ...

# %%
import pandas as pd
from natsort import natsorted
#pull out header for indexing later
with open('ion5.sorted.txt', 'rU') as f:
    first_line = f.readline()
    OTUhead = first_line.split('\t')[0]
    
#now load sorted "raw" OTU table into dataframe
dfsorted = pd.read_csv('ion5.sorted.txt', sep='\t')
dfsorted.set_index(OTUhead, inplace=True)

#now we want to drop last column
header = ['m5-301-1', 'm5-301-2', 'm5-500-1', 'm5-500-2', 'm5-712-1', 
        'm5-712-2', 'm5-736-1', 'm5-736-2', 'm5-744-1', 'm5-744-2', 
        'm5-755-1', 'm5-755-2', 'm5-757-1', 'm5-757-2', 'm5-766-1', 'm5-766-2']
dfcleaned = dfsorted.reindex(columns=header, index=natsorted(dfsorted.index))

#now drop OTUs where they are all zero
fs = dfcleaned.sum(axis=0)
filtered = pd.DataFrame(dfcleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(dfsorted), len(dfsorted.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv('ion5.sorted.nomock.txt', sep='\t')

#now convert to biom
# !amptk taxonomy -f otudb.cluster.otus.fa -o ion5_raw -i ion5.sorted.nomock.txt -d ITS2 \
-m ion5.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# 2473 17 1584 16
# -------------------------------------------------------
# [01:23:48 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [01:23:48 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [01:23:48 PM]: Loading FASTA Records
# [01:23:48 PM]: 2,480 OTUs
# [01:23:48 PM]: Appending taxonomy to OTU table and OTUs
# [01:23:48 PM]: Generating phylogenetic tree
# [01:23:59 PM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [01:23:59 PM]: Classic OTU table with taxonomy: ion5_raw.otu_table.taxonomy.txt
# [01:24:01 PM]: BIOM OTU table created: ion5_raw.biom
# [01:24:01 PM]: OTUs with taxonomy: ion5_raw.otus.taxonomy.fa
# [01:24:01 PM]: OTU phylogeny: ion5_raw.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq
# !/Users/jon/amptk/util/phyloseq_graphs.R ion5_raw.biom ion5_raw.tree.phy ion5_raw
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# There were 12 warnings (use warnings() to see them)
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1517762
# Run 1 stress 0.2013717
# Run 2 stress 0.1553845
# Run 3 stress 0.1553846
# Run 4 stress 0.2038471
# Run 5 stress 0.1539358
# Run 6 stress 0.1539353
# Run 7 stress 0.1539353
# Run 8 stress 0.1539354
# Run 9 stress 0.1902329
# Run 10 stress 0.2142988
# Run 11 stress 0.1539359
# Run 12 stress 0.2093007
# Run 13 stress 0.1553844
# Run 14 stress 0.2157074
# Run 15 stress 0.153936
# Run 16 stress 0.1539355
# Run 17 stress 0.1553844
# Run 18 stress 0.1911059
# Run 19 stress 0.2157075
# Run 20 stress 0.2038472
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.36862 0.36862  4.3565 0.23733 0.0761 .
# Residuals                 14   1.18458 0.08461         0.76267
# Total                     15   1.55319                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###NMDS using jaccard
# ![alt text](ion5_raw.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4697 0.46971  1.0284 0.06843 0.4451
# Residuals                 14    6.3946 0.45676         0.93157
# Total                     15    6.8643                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](ion5_raw.Treatment.braycurtis.pdf)

# %%
#now get filtered BIOM
# !amptk taxonomy -f ion5.filtered.otus.fa -i ion5.final.txt -d ITS2 -m ion5.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# -------------------------------------------------------
# [10:23:54 AM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [10:23:55 AM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [10:23:55 AM]: Loading FASTA Records
# [10:23:55 AM]: 369 OTUs
# [10:23:55 AM]: Appending taxonomy to OTU table and OTUs
# [10:23:55 AM]: Generating phylogenetic tree
# [10:23:55 AM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [10:23:55 AM]: Classic OTU table with taxonomy: ion5.otu_table.taxonomy.txt
# [10:23:57 AM]: BIOM OTU table created: ion5.biom
# [10:23:57 AM]: OTUs with taxonomy: ion5.otus.taxonomy.fa
# [10:23:57 AM]: OTU phylogeny: ion5.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq
# !/Users/jon/amptk/util/phyloseq_graphs.R ion5.biom ion5.tree.phy ion5_filtered
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.2088984
# Run 1 stress 0.2122824
# Run 2 stress 0.2085693
# ... New best solution
# ... Procrustes: rmse 0.03378664  max resid 0.08989316
# Run 3 stress 0.1932874
# ... New best solution
# ... Procrustes: rmse 0.1187702  max resid 0.269162
# Run 4 stress 0.2298542
# Run 5 stress 0.2219253
# Run 6 stress 0.2020158
# Run 7 stress 0.2461529
# Run 8 stress 0.2098963
# Run 9 stress 0.2296379
# Run 10 stress 0.2201646
# Run 11 stress 0.1929808
# ... New best solution
# ... Procrustes: rmse 0.02307756  max resid 0.06341198
# Run 12 stress 0.2122822
# Run 13 stress 0.2158179
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4253 0.42529   1.889 0.11889  0.188
# Residuals                 14    3.1520 0.22514         0.88111
# Total                     15    3.5773                 1.00000
# ```
# ###NMDS using raup
# ![alt text](ion5_filtered.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4713 0.47133  1.0239 0.06815 0.4518
# Residuals                 14    6.4444 0.46032         0.93185
# Total                     15    6.9157                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](ion5_filtered.Treatment.braycurtis.pdf)

# %%
#run ion5 no subtraction filter
# !amptk filter -i ion5.otu_table.txt -f otudb.cluster.otus.fa -o ion5_nosub -b m5-SynMock2-8000 -m synmock
# Out:
# -------------------------------------------------------
# [02:29:30 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:29:30 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:29:30 PM]: Loading OTU table: ion5.otu_table.txt
# [02:29:30 PM]: OTU table contains 2473 OTUs
# [02:29:30 PM]: Mapping OTUs to Mock Community (USEARCH)
# [02:29:30 PM]: Sorting OTU table naturally
# [02:29:30 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [02:29:30 PM]: Normalizing OTU table to number of reads per sample
# [02:29:30 PM]: Index bleed, mock into samples: 0.174878%.  Index bleed, samples into mock: 0.103002%.
# [02:29:30 PM]: Will use value of 0.200000% for index-bleed OTU filtering.
# [02:29:31 PM]: Filtering OTU table down to 1358 OTUs
# [02:29:31 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# ...

# %%
#now get filtered BIOM
# !amptk taxonomy -f ion5_nosub.filtered.otus.fa -i ion5_nosub.final.txt -d ITS2 -m ion5.mapping_file.txt -t otudb.cluster.otus.taxonomy.txt
# Out:
# -------------------------------------------------------
# [02:30:08 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [02:30:09 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [02:30:09 PM]: Loading FASTA Records
# [02:30:09 PM]: 1,358 OTUs
# [02:30:09 PM]: Appending taxonomy to OTU table and OTUs
# [02:30:09 PM]: Generating phylogenetic tree
# [02:30:12 PM]: Taxonomy finished: otudb.cluster.otus.taxonomy.txt
# [02:30:12 PM]: Classic OTU table with taxonomy: ion5_nosub.otu_table.taxonomy.txt
# [02:30:14 PM]: BIOM OTU table created: ion5_nosub.biom
# [02:30:14 PM]: OTUs with taxonomy: ion5_nosub.otus.taxonomy.fa
# [02:30:14 PM]: OTU phylogeny: ion5_nosub.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq
# !/Users/jon/amptk/util/phyloseq_graphs.R ion5_nosub.biom ion5_nosub.tree.phy ion5_nosub
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.149634
# Run 1 stress 0.1533488
# Run 2 stress 0.1937315
# Run 3 stress 0.1504872
# Run 4 stress 0.1504872
# Run 5 stress 0.1771024
# Run 6 stress 0.149634
# ... Procrustes: rmse 7.505712e-05  max resid 0.0001744291
# ... Similar to previous best
# Run 7 stress 0.1801135
# Run 8 stress 0.1504872
# Run 9 stress 0.1801135
# Run 10 stress 0.1937314
# Run 11 stress 0.149634
# ... New best solution
# ... Procrustes: rmse 1.063378e-05  max resid 2.461795e-05
# ... Similar to previous best
# Run 12 stress 0.1504872
# Run 13 stress 0.153349
# Run 14 stress 0.1504872
# Run 15 stress 0.149634
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4751 0.47510  4.9297 0.26042 0.0373 *
# Residuals                 14    1.3493 0.09638         0.73958
# Total                     15    1.8244                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###NMDS using raup
# ![alt text](ion5_nosub.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4702 0.47019  1.0286 0.06844 0.4414
# Residuals                 14    6.3996 0.45711         0.93156
# Total                     15    6.8697                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](ion5_nosub.Treatment.braycurtis.pdf)

# %% [markdown]
# ![alt text](summary.png)

# %%
#convert OTU tables for Michelle's R method, 
# !amptk meta -i ion3.sorted.nomock.txt -m all_data.meta.csv -o ion3_raw.meta.csv
# Out:
# Working on complete OTU table: found 1654 OTUs
# ERROR m4C-301-1, m4C-301-2, m4C-500-1, m4C-500-2, m4C-712-1, m4C-712-2, m4C-736-1, m4C-736-2, m4C-744-1, m4C-744-2, m4C-755-1, m4C-755-2, m4C-757-1, m4C-757-2, m4C-766-1, m4C-766-2, m4C-mock3-16000, m4C-mock3-32000a, m4C-mock3-32000b, m4C-stds, m4A-301-1, m4A-301-2, m4A-500-1, m4A-500-2, m4A-712-1, m4A-712-2, m4A-736-1, m4A-736-2, m4A-744-1, m4A-744-2, m4A-755-1, m4A-755-2, m4A-757-1, m4A-757-2, m4A-766-1, m4A-766-2, m4A-mock3-16000, m4A-mock3-32000a, m4A-mock3-32000b, m4A-stds, m3-mock3-3200a, m3-mock3-16000, m3-mock3-32000b, m3-stds, m5-301-1, m5-301-2, m5-500-1, m5-500-2, m5-712-1, m5-712-2, m5-736-1, m5-736-2, m5-744-1, m5-744-2, m5-755-1, m5-755-2, m5-757-1, m5-757-2, m5-766-1, m5-766-2, m5-SynMock1-8000, m5-SynMock2-8000, m5-mock3.0-16000, m5-mock3.5-16000: not found in OTU table. Names must max exactly.

# %%
# !amptk meta -i ion3.final.txt -m all_data.meta.csv -o ion3_filtered.meta.csv
# Out:
# Working on complete OTU table: found 397 OTUs
# ERROR m4C-301-1, m4C-301-2, m4C-500-1, m4C-500-2, m4C-712-1, m4C-712-2, m4C-736-1, m4C-736-2, m4C-744-1, m4C-744-2, m4C-755-1, m4C-755-2, m4C-757-1, m4C-757-2, m4C-766-1, m4C-766-2, m4C-mock3-16000, m4C-mock3-32000a, m4C-mock3-32000b, m4C-stds, m4A-301-1, m4A-301-2, m4A-500-1, m4A-500-2, m4A-712-1, m4A-712-2, m4A-736-1, m4A-736-2, m4A-744-1, m4A-744-2, m4A-755-1, m4A-755-2, m4A-757-1, m4A-757-2, m4A-766-1, m4A-766-2, m4A-mock3-16000, m4A-mock3-32000a, m4A-mock3-32000b, m4A-stds, m3-mock3-3200a, m3-mock3-16000, m3-mock3-32000b, m3-stds, m5-301-1, m5-301-2, m5-500-1, m5-500-2, m5-712-1, m5-712-2, m5-736-1, m5-736-2, m5-744-1, m5-744-2, m5-755-1, m5-755-2, m5-757-1, m5-757-2, m5-766-1, m5-766-2, m5-SynMock1-8000, m5-SynMock2-8000, m5-mock3.0-16000, m5-mock3.5-16000: not found in OTU table. Names must max exactly.

# %%
# !amptk meta -i miseq4a.sorted.nomock.txt -m all_data.meta.csv -o miseq4a_raw.meta.csv
# Out:
# Working on complete OTU table: found 2179 OTUs
# ERROR m4C-301-1, m4C-301-2, m4C-500-1, m4C-500-2, m4C-712-1, m4C-712-2, m4C-736-1, m4C-736-2, m4C-744-1, m4C-744-2, m4C-755-1, m4C-755-2, m4C-757-1, m4C-757-2, m4C-766-1, m4C-766-2, m4C-mock3-16000, m4C-mock3-32000a, m4C-mock3-32000b, m4C-stds, m4A-mock3-16000, m4A-mock3-32000a, m4A-mock3-32000b, m4A-stds, m3-301-1, m3-301-2, m3-500-1, m3-500-2, m3-712-1, m3-712-2, m3-736-1, m3-736-2, m3-744-1, m3-744-2, m3-755-1, m3-755-2, m3-757-2, m3-766-1, m3-766-2, m3-mock3-3200a, m3-mock3-16000, m3-mock3-32000b, m3-stds, m5-301-1, m5-301-2, m5-500-1, m5-500-2, m5-712-1, m5-712-2, m5-736-1, m5-736-2, m5-744-1, m5-744-2, m5-755-1, m5-755-2, m5-757-1, m5-757-2, m5-766-1, m5-766-2, m5-SynMock1-8000, m5-SynMock2-8000, m5-mock3.0-16000, m5-mock3.5-16000: not found in OTU table. Names must max exactly.

# %%
# !amptk meta -i miseq4a.final.txt -m all_data.meta.csv -o miseq4a_filtered.meta.csv
# Out:
# Working on complete OTU table: found 446 OTUs
# ERROR m4C-301-1, m4C-301-2, m4C-500-1, m4C-500-2, m4C-712-1, m4C-712-2, m4C-736-1, m4C-736-2, m4C-744-1, m4C-744-2, m4C-755-1, m4C-755-2, m4C-757-1, m4C-757-2, m4C-766-1, m4C-766-2, m4C-mock3-16000, m4C-mock3-32000a, m4C-mock3-32000b, m4C-stds, m4A-mock3-16000, m4A-mock3-32000a, m4A-mock3-32000b, m4A-stds, m3-301-1, m3-301-2, m3-500-1, m3-500-2, m3-712-1, m3-712-2, m3-736-1, m3-736-2, m3-744-1, m3-744-2, m3-755-1, m3-755-2, m3-757-2, m3-766-1, m3-766-2, m3-mock3-3200a, m3-mock3-16000, m3-mock3-32000b, m3-stds, m5-301-1, m5-301-2, m5-500-1, m5-500-2, m5-712-1, m5-712-2, m5-736-1, m5-736-2, m5-744-1, m5-744-2, m5-755-1, m5-755-2, m5-757-1, m5-757-2, m5-766-1, m5-766-2, m5-SynMock1-8000, m5-SynMock2-8000, m5-mock3.0-16000, m5-mock3.5-16000: not found in OTU table. Names must max exactly.

# %%
# !amptk meta -i miseq4c.sorted.nomock.txt -m all_data.meta.csv -o miseq4c_raw.meta.csv
# Out:
# Working on complete OTU table: found 2109 OTUs
# ERROR m4C-mock3-16000, m4C-mock3-32000a, m4C-mock3-32000b, m4C-stds, m4A-301-1, m4A-301-2, m4A-500-1, m4A-500-2, m4A-712-1, m4A-712-2, m4A-736-1, m4A-736-2, m4A-744-1, m4A-744-2, m4A-755-1, m4A-755-2, m4A-757-1, m4A-757-2, m4A-766-1, m4A-766-2, m4A-mock3-16000, m4A-mock3-32000a, m4A-mock3-32000b, m4A-stds, m3-301-1, m3-301-2, m3-500-1, m3-500-2, m3-712-1, m3-712-2, m3-736-1, m3-736-2, m3-744-1, m3-744-2, m3-755-1, m3-755-2, m3-757-2, m3-766-1, m3-766-2, m3-mock3-3200a, m3-mock3-16000, m3-mock3-32000b, m3-stds, m5-301-1, m5-301-2, m5-500-1, m5-500-2, m5-712-1, m5-712-2, m5-736-1, m5-736-2, m5-744-1, m5-744-2, m5-755-1, m5-755-2, m5-757-1, m5-757-2, m5-766-1, m5-766-2, m5-SynMock1-8000, m5-SynMock2-8000, m5-mock3.0-16000, m5-mock3.5-16000: not found in OTU table. Names must max exactly.

# %%
# !amptk meta -i miseq4c.final.txt -m all_data.meta.csv -o miseq4c_filtered.meta.csv
# Out:
# Working on complete OTU table: found 502 OTUs
# ERROR m4C-mock3-16000, m4C-mock3-32000a, m4C-mock3-32000b, m4C-stds, m4A-301-1, m4A-301-2, m4A-500-1, m4A-500-2, m4A-712-1, m4A-712-2, m4A-736-1, m4A-736-2, m4A-744-1, m4A-744-2, m4A-755-1, m4A-755-2, m4A-757-1, m4A-757-2, m4A-766-1, m4A-766-2, m4A-mock3-16000, m4A-mock3-32000a, m4A-mock3-32000b, m4A-stds, m3-301-1, m3-301-2, m3-500-1, m3-500-2, m3-712-1, m3-712-2, m3-736-1, m3-736-2, m3-744-1, m3-744-2, m3-755-1, m3-755-2, m3-757-2, m3-766-1, m3-766-2, m3-mock3-3200a, m3-mock3-16000, m3-mock3-32000b, m3-stds, m5-301-1, m5-301-2, m5-500-1, m5-500-2, m5-712-1, m5-712-2, m5-736-1, m5-736-2, m5-744-1, m5-744-2, m5-755-1, m5-755-2, m5-757-1, m5-757-2, m5-766-1, m5-766-2, m5-SynMock1-8000, m5-SynMock2-8000, m5-mock3.0-16000, m5-mock3.5-16000: not found in OTU table. Names must max exactly.

# %%
# !amptk meta -i ion5.sorted.nomock.txt -m all_data.meta.csv -o ion5_raw.meta.csv
# Out:
# Working on complete OTU table: found 1584 OTUs
# ERROR m4C-301-1, m4C-301-2, m4C-500-1, m4C-500-2, m4C-712-1, m4C-712-2, m4C-736-1, m4C-736-2, m4C-744-1, m4C-744-2, m4C-755-1, m4C-755-2, m4C-757-1, m4C-757-2, m4C-766-1, m4C-766-2, m4C-mock3-16000, m4C-mock3-32000a, m4C-mock3-32000b, m4C-stds, m4A-301-1, m4A-301-2, m4A-500-1, m4A-500-2, m4A-712-1, m4A-712-2, m4A-736-1, m4A-736-2, m4A-744-1, m4A-744-2, m4A-755-1, m4A-755-2, m4A-757-1, m4A-757-2, m4A-766-1, m4A-766-2, m4A-mock3-16000, m4A-mock3-32000a, m4A-mock3-32000b, m4A-stds, m3-301-1, m3-301-2, m3-500-1, m3-500-2, m3-712-1, m3-712-2, m3-736-1, m3-736-2, m3-744-1, m3-744-2, m3-755-1, m3-755-2, m3-757-2, m3-766-1, m3-766-2, m3-mock3-3200a, m3-mock3-16000, m3-mock3-32000b, m3-stds, m5-SynMock1-8000, m5-SynMock2-8000, m5-mock3.0-16000, m5-mock3.5-16000: not found in OTU table. Names must max exactly.

# %%
# !amptk meta -i ion5.final.txt -m all_data.meta.csv -o ion5_filtered.meta.csv
# Out:
# Working on complete OTU table: found 369 OTUs
# ERROR m4C-301-1, m4C-301-2, m4C-500-1, m4C-500-2, m4C-712-1, m4C-712-2, m4C-736-1, m4C-736-2, m4C-744-1, m4C-744-2, m4C-755-1, m4C-755-2, m4C-757-1, m4C-757-2, m4C-766-1, m4C-766-2, m4C-mock3-16000, m4C-mock3-32000a, m4C-mock3-32000b, m4C-stds, m4A-301-1, m4A-301-2, m4A-500-1, m4A-500-2, m4A-712-1, m4A-712-2, m4A-736-1, m4A-736-2, m4A-744-1, m4A-744-2, m4A-755-1, m4A-755-2, m4A-757-1, m4A-757-2, m4A-766-1, m4A-766-2, m4A-mock3-16000, m4A-mock3-32000a, m4A-mock3-32000b, m4A-stds, m3-301-1, m3-301-2, m3-500-1, m3-500-2, m3-712-1, m3-712-2, m3-736-1, m3-736-2, m3-744-1, m3-744-2, m3-755-1, m3-755-2, m3-757-2, m3-766-1, m3-766-2, m3-mock3-3200a, m3-mock3-16000, m3-mock3-32000b, m3-stds, m5-SynMock1-8000, m5-SynMock2-8000, m5-mock3.0-16000, m5-mock3.5-16000: not found in OTU table. Names must max exactly.

# %%
#now lets go back and process each of these runs separately, i.e. akin to how you would normally run amptk
#first select the reads you want from original demuxing
# !amptk remove -i ion3.demux.fq -l m3-mock3-32000b m3-mock3-3200a m3-stds -o ion3.cleaned.demux.fq
# !amptk show -i ion3.cleaned.demux.fq
# Out:
# Removed 3 samples
# Kept 2407551 reads out of 2879144 total reads
# ----------------------------------
# Found 16 barcoded samples
#               Sample:  Count
#             m3-766-1:  205305
#       m3-mock3-16000:  183277
#             m3-301-2:  170879
#             m3-744-2:  160175
#             m3-500-1:  158095
#             m3-500-2:  152733
#             m3-766-2:  152560
#             m3-301-1:  151264
#             m3-755-1:  150229
#             m3-736-1:  148309
#             m3-755-2:  138299
#             m3-736-2:  134956
#             m3-757-2:  134727
#             m3-744-1:  130294
#             m3-712-1:  125701
#             m3-712-2:  110748
# ----------------------------------
# Read count: 2407551
# Read Length: 250 bp
# ----------------------------------

# %%
#now cluster the cleaned up data
# !amptk cluster -i ion3.cleaned.demux.fq -o i3
# Out:
# -------------------------------------------------------
# [03:01:11 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:01:11 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:01:11 PM]: Loading FASTQ Records
# [03:01:13 PM]: 2,407,551 reads (1.2 GB)
# [03:01:13 PM]: Quality Filtering, expected errors < 1.0
# [03:02:09 PM]: 1,416,710 reads passed
# [03:02:09 PM]: De-replication (remove duplicate reads)
# [03:02:14 PM]: 57,855 reads passed
# [03:02:14 PM]: Clustering OTUs (UPARSE)
# [03:02:21 PM]: 1,057 OTUs
# [03:02:21 PM]: Cleaning up padding from OTUs
# [03:02:21 PM]: Mapping Reads to OTUs and Building OTU table
# [03:06:49 PM]: 1,938,679 reads mapped to OTUs (81%)
# -------------------------------------------------------
# OTU Clustering Script has Finished Successfully
# -------------------------------------------------------
# Clustered OTUs: /Users/jon/projects/synmock_paper/i3.cluster.otus.fa
# ...

# %%
#run filtering with no subtraction first
# !amptk filter -i i3.otu_table.txt -f i3.cluster.otus.fa -b m3-mock3-16000 -m mock3 -c in -o i3_nosub
# Out:
# -------------------------------------------------------
# [03:07:47 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:07:47 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:07:47 PM]: Loading OTU table: i3.otu_table.txt
# [03:07:47 PM]: OTU table contains 1057 OTUs
# [03:07:47 PM]: Mapping OTUs to Mock Community (USEARCH)
# [03:07:47 PM]: Sorting OTU table naturally
# [03:07:47 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [03:07:47 PM]: Normalizing OTU table to number of reads per sample
# [03:07:47 PM]: Index bleed, samples into mock: 0.047999%.
# [03:07:47 PM]: Will use value of 0.100000% for index-bleed OTU filtering.
# [03:07:48 PM]: Filtering OTU table down to 1035 OTUs
# [03:07:48 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# OTU Table Stats:      i3_nosub.stats.txt
# ...

# %%
#get raw data into biom format
import pandas as pd
from natsort import natsorted
#pull out header for indexing later
with open('i3_nosub.sorted.txt', 'rU') as f:
    first_line = f.readline()
    OTUhead = first_line.split('\t')[0]
    
#now load sorted "raw" OTU table into dataframe
dfsorted = pd.read_csv('i3_nosub.sorted.txt', sep='\t')
dfsorted.set_index(OTUhead, inplace=True)

#now we want to drop last column
header = ['m3-301-1', 'm3-301-2', 'm3-500-1', 'm3-500-2', 'm3-712-1', 'm3-712-2', 
        'm3-736-1', 'm3-736-2', 'm3-744-1', 'm3-744-2', 'm3-755-1', 'm3-755-2',
        'm3-757-2', 'm3-766-1', 'm3-766-2']
dfcleaned = dfsorted.reindex(columns=header, index=natsorted(dfsorted.index))

#now drop OTUs where they are all zero
fs = dfcleaned.sum(axis=0)
filtered = pd.DataFrame(dfcleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(dfsorted), len(dfsorted.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv('i3.sorted.nomock.txt', sep='\t')

#now convert to biom
# !amptk taxonomy -f i3.cluster.otus.fa -o i3_raw -i i3.sorted.nomock.txt -d ITS2 -m ion3.mapping_file.txt
# Out:
# 1057 16 1051 15
# -------------------------------------------------------
# [03:10:29 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:10:29 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:10:29 PM]: Loading FASTA Records
# [03:10:29 PM]: 1,057 OTUs
# [03:10:29 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [03:10:42 PM]: Classifying OTUs with UTAX (USEARCH)
# [03:10:42 PM]: Classifying OTUs with SINTAX (USEARCH)
# [03:13:40 PM]: Appending taxonomy to OTU table and OTUs
# [03:13:40 PM]: Generating phylogenetic tree
# [03:13:43 PM]: Taxonomy finished: i3_raw.taxonomy.txt
# [03:13:43 PM]: Classic OTU table with taxonomy: i3_raw.otu_table.taxonomy.txt
# [03:13:44 PM]: BIOM OTU table created: i3_raw.biom
# [03:13:44 PM]: OTUs with taxonomy: i3_raw.otus.taxonomy.fa
# [03:13:44 PM]: OTU phylogeny: i3_raw.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R i3_raw.biom i3_raw.tree.phy i3_raw
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# There were 21 warnings (use warnings() to see them)
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1519626
# Run 1 stress 0.1722504
# Run 2 stress 0.1520057
# ... Procrustes: rmse 0.005564915  max resid 0.01840075
# Run 3 stress 0.1621586
# Run 4 stress 0.1704118
# Run 5 stress 0.1709248
# Run 6 stress 0.1519513
# ... New best solution
# ... Procrustes: rmse 0.002580261  max resid 0.008318369
# ... Similar to previous best
# Run 7 stress 0.1706664
# Run 8 stress 0.1599569
# Run 9 stress 0.1519513
# ... Procrustes: rmse 4.442832e-05  max resid 0.0001306989
# ... Similar to previous best
# Run 10 stress 0.1617357
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.20506 0.20506  1.7094 0.11621 0.3175
# Residuals                 13   1.55944 0.11996         0.88379
# Total                     14   1.76449                 1.00000
# ```
# ###NMDS using raup
# ![alt text](i3_raw.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4533 0.45329  1.0128 0.07228 0.4644
# Residuals                 13    5.8185 0.44757         0.92772
# Total                     14    6.2717                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](i3_raw.Treatment.braycurtis.pdf)

# %%
#convert no subtraction to biom
# !amptk taxonomy -f i3_nosub.filtered.otus.fa -o i3_nosub -i i3_nosub.final.txt -d ITS2 -m ion3.mapping_file.txt
# Out:
# -------------------------------------------------------
# [03:17:52 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:17:52 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:17:52 PM]: Loading FASTA Records
# [03:17:52 PM]: 1,035 OTUs
# [03:17:52 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [03:18:02 PM]: Classifying OTUs with UTAX (USEARCH)
# [03:18:03 PM]: Classifying OTUs with SINTAX (USEARCH)
# [03:21:00 PM]: Appending taxonomy to OTU table and OTUs
# [03:21:01 PM]: Generating phylogenetic tree
# [03:21:03 PM]: Taxonomy finished: i3_nosub.taxonomy.txt
# [03:21:03 PM]: Classic OTU table with taxonomy: i3_nosub.otu_table.taxonomy.txt
# [03:21:05 PM]: BIOM OTU table created: i3_nosub.biom
# [03:21:05 PM]: OTUs with taxonomy: i3_nosub.otus.taxonomy.fa
# [03:21:05 PM]: OTU phylogeny: i3_nosub.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R i3_nosub.biom i3_nosub.tree.phy i3_nosub
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1482358
# Run 1 stress 0.1591481
# Run 2 stress 0.1482358
# ... Procrustes: rmse 8.489064e-06  max resid 1.375638e-05
# ... Similar to previous best
# Run 3 stress 0.1655535
# Run 4 stress 0.2988611
# Run 5 stress 0.1694109
# Run 6 stress 0.1591476
# Run 7 stress 0.165558
# Run 8 stress 0.1675681
# Run 9 stress 0.1675665
# Run 10 stress 0.1675664
# Run 11 stress 0.1667055
# Run 12 stress 0.1482358
# ... Procrustes: rmse 0.000125241  max resid 0.0003721117
# ... Similar to previous best
# Run 13 stress 0.1630948
# Run 14 stress 0.1719454
# Run 15 stress 0.1591471
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.26727 0.26727  2.1073 0.13949 0.2208
# Residuals                 13   1.64879 0.12683         0.86051
# Total                     14   1.91606                 1.00000
# ```
# ###NMDS using raup
# ![alt text](i3_raw.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4524 0.45240  1.0095 0.07206 0.4718
# Residuals                 13    5.8260 0.44815         0.92794
# Total                     14    6.2783                 1.00000
#
# ```
# ###NMDS using braycurtis
# ![alt text](i3_raw.Treatment.braycurtis.pdf)

# %%
#now run filtering with auto subtraction filter
#run filtering with no subtraction first
# !amptk filter -i i3.otu_table.txt -f i3.cluster.otus.fa -b m3-mock3-16000 -m mock3 -c in -o i3 -s auto
# Out:
# -------------------------------------------------------
# [03:24:56 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:24:56 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:24:56 PM]: Loading OTU table: i3.otu_table.txt
# [03:24:56 PM]: OTU table contains 1057 OTUs
# [03:24:56 PM]: Mapping OTUs to Mock Community (USEARCH)
# [03:24:57 PM]: Sorting OTU table naturally
# [03:24:57 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [03:24:57 PM]: Normalizing OTU table to number of reads per sample
# [03:24:57 PM]: Index bleed, samples into mock: 0.047999%.
# [03:24:57 PM]: Will use value of 0.100000% for index-bleed OTU filtering.
# [03:24:57 PM]: Auto subtract filter set to 31
# [03:24:57 PM]: Subtracting 31 from OTU table
# [03:24:57 PM]: Filtering OTU table down to 362 OTUs
# [03:24:57 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# ...

# %%
# !amptk taxonomy -f i3.filtered.otus.fa -i i3.final.txt -m ion3.mapping_file.txt -d ITS2
# Out:
# -------------------------------------------------------
# [03:25:34 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:25:34 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:25:34 PM]: Loading FASTA Records
# [03:25:34 PM]: 362 OTUs
# [03:25:34 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [03:25:39 PM]: Classifying OTUs with UTAX (USEARCH)
# [03:25:39 PM]: Classifying OTUs with SINTAX (USEARCH)
# [03:27:11 PM]: Appending taxonomy to OTU table and OTUs
# [03:27:11 PM]: Generating phylogenetic tree
# [03:27:11 PM]: Taxonomy finished: i3.taxonomy.txt
# [03:27:11 PM]: Classic OTU table with taxonomy: i3.otu_table.taxonomy.txt
# [03:27:12 PM]: BIOM OTU table created: i3.biom
# [03:27:12 PM]: OTUs with taxonomy: i3.otus.taxonomy.fa
# [03:27:12 PM]: OTU phylogeny: i3.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R i3.biom i3.tree.phy i3
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.2033973
# Run 1 stress 0.1957146
# ... New best solution
# ... Procrustes: rmse 0.1952427  max resid 0.6547199
# Run 2 stress 0.2118633
# Run 3 stress 0.2039372
# Run 4 stress 0.2173894
# Run 5 stress 0.2114433
# Run 6 stress 0.215529
# Run 7 stress 0.2144408
# Run 8 stress 0.2355701
# Run 9 stress 0.290856
# Run 10 stress 0.1990067
# Run 11 stress 0.1957148
# ... Procrustes: rmse 9.06666e-05  max resid 0.0001956514
# ... Similar to previous best
# Run 12 stress 0.2237672
# Run 13 stress 0.1957148
# ... Procrustes: rmse 0.0002491816  max resid 0.0005394005
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model     R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.41328 0.41328  2.1657 0.1428 0.1381
# Residuals                 13   2.48086 0.19084         0.8572
# Total                     14   2.89415                 1.0000
# ```
# ###NMDS using raup
# ![alt text](i3.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4537 0.45371  1.0057 0.07181 0.4748
# Residuals                 13    5.8648 0.45114         0.92819
# Total                     14    6.3185                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](i3.Treatment.braycurtis.pdf)

# %%
#Ok, move onto miseqA run
#now lets go back and process each of these runs separately, i.e. akin to how you would normally run amptk
#first select the reads you want from original demuxing
# !amptk remove -i m4a.demux.fq -l m4A-mock3-32000b m4A-mock3-32000a m4A-stds -o miseq4a.cleaned.demux.fq
# !amptk show -i miseq4a.cleaned.demux.fq
# Out:
# Removed 3 samples
# Kept 4809024 reads out of 5628414 total reads
# ----------------------------------
# Found 17 barcoded samples
#               Sample:  Count
#            m4A-500-1:  332586
#            m4A-766-2:  321816
#            m4A-755-1:  302871
#            m4A-766-1:  302038
#            m4A-755-2:  293758
#            m4A-301-2:  293694
#      m4A-mock3-16000:  282380
#            m4A-744-1:  281436
#            m4A-757-1:  280341
#            m4A-736-1:  277532
#            m4A-757-2:  274936
#            m4A-500-2:  274015
#            m4A-301-1:  268266
#            m4A-712-1:  264849
#            m4A-736-2:  261875
#            m4A-744-2:  256458
#            m4A-712-2:  240173
# ----------------------------------
# Read count: 4809024
# Read Length: 250 bp
# ----------------------------------

# %%
#now cluster the cleaned up data
# !amptk cluster -i miseq4a.cleaned.demux.fq -o m4a
# Out:
# -------------------------------------------------------
# [03:46:30 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:46:30 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:46:30 PM]: Loading FASTQ Records
# [03:46:33 PM]: 4,809,024 reads (2.4 GB)
# [03:46:33 PM]: Quality Filtering, expected errors < 1.0
# [03:48:30 PM]: 4,462,394 reads passed
# [03:48:30 PM]: De-replication (remove duplicate reads)
# [03:48:44 PM]: 190,777 reads passed
# [03:48:45 PM]: Clustering OTUs (UPARSE)
# [03:49:01 PM]: 1,803 OTUs
# [03:49:01 PM]: Cleaning up padding from OTUs
# [03:49:01 PM]: Mapping Reads to OTUs and Building OTU table
# [03:56:43 PM]: 4,611,275 reads mapped to OTUs (96%)
# -------------------------------------------------------
# OTU Clustering Script has Finished Successfully
# -------------------------------------------------------
# Clustered OTUs: /Users/jon/projects/synmock_paper/m4a.cluster.otus.fa
# ...

# %%
#run filtering with no subtraction first
# !amptk filter -i m4a.otu_table.txt -f m4a.cluster.otus.fa -b m4A-mock3-16000 -m mock3 -c in -o m4a_nosub -p 0.005
# Out:
# -------------------------------------------------------
# [05:07:35 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [05:07:35 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [05:07:35 PM]: Loading OTU table: m4a.otu_table.txt
# [05:07:35 PM]: OTU table contains 1798 OTUs
# [05:07:35 PM]: Mapping OTUs to Mock Community (USEARCH)
# [05:07:35 PM]: Sorting OTU table naturally
# [05:07:35 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [05:07:35 PM]: Normalizing OTU table to number of reads per sample
# [05:07:35 PM]: Index bleed, samples into mock: 0.054001%.
# [05:07:35 PM]: Overwriting auto detect index-bleed, setting to 0.500000%
# [05:07:36 PM]: Filtering OTU table down to 1752 OTUs
# [05:07:36 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# OTU Table Stats:      m4a_nosub.stats.txt
# ...

# %%
#get raw data into biom format
import pandas as pd
from natsort import natsorted
#pull out header for indexing later
with open('m4a_nosub.sorted.txt', 'rU') as f:
    first_line = f.readline()
    OTUhead = first_line.split('\t')[0]
    
#now load sorted "raw" OTU table into dataframe
dfsorted = pd.read_csv('m4a_nosub.sorted.txt', sep='\t')
dfsorted.set_index(OTUhead, inplace=True)

#now we want to drop last column
header = ['m4A-301-1', 'm4A-301-2', 'm4A-500-1', 'm4A-500-2', 'm4A-712-1', 
           'm4A-712-2', 'm4A-736-1', 'm4A-736-2', 'm4A-744-1', 'm4A-744-2', 
           'm4A-755-1', 'm4A-755-2', 'm4A-757-1', 'm4A-757-2', 'm4A-766-1', 'm4A-766-2']
dfcleaned = dfsorted.reindex(columns=header, index=natsorted(dfsorted.index))

#now drop OTUs where they are all zero
fs = dfcleaned.sum(axis=0)
filtered = pd.DataFrame(dfcleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(dfsorted), len(dfsorted.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv('m4a.sorted.nomock.txt', sep='\t')

#now convert to biom
# !amptk taxonomy -f m4a.cluster.otus.fa -o m4a_raw -i m4a.sorted.nomock.txt -d ITS2 -m m4a.mapping_file.txt
# Out:
# 1798 17 1797 16
# -------------------------------------------------------
# [03:57:02 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [03:57:02 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [03:57:02 PM]: Loading FASTA Records
# [03:57:02 PM]: 1,803 OTUs
# [03:57:02 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [03:57:20 PM]: Classifying OTUs with UTAX (USEARCH)
# [03:57:21 PM]: Classifying OTUs with SINTAX (USEARCH)
# [04:01:48 PM]: Appending taxonomy to OTU table and OTUs
# [04:01:49 PM]: Generating phylogenetic tree
# [04:01:55 PM]: Taxonomy finished: m4a_raw.taxonomy.txt
# [04:01:55 PM]: Classic OTU table with taxonomy: m4a_raw.otu_table.taxonomy.txt
# [04:01:57 PM]: BIOM OTU table created: m4a_raw.biom
# [04:01:57 PM]: OTUs with taxonomy: m4a_raw.otus.taxonomy.fa
# [04:01:57 PM]: OTU phylogeny: m4a_raw.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R m4a_raw.biom m4a_raw.tree.phy m4a_raw
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# There were 27 warnings (use warnings() to see them)
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1594448
# Run 1 stress 0.1531269
# ... New best solution
# ... Procrustes: rmse 0.1510224  max resid 0.3898098
# Run 2 stress 0.1609605
# Run 3 stress 0.1609604
# Run 4 stress 0.1527909
# ... New best solution
# ... Procrustes: rmse 0.1883387  max resid 0.5795488
# Run 5 stress 0.2179276
# Run 6 stress 0.153127
# ... Procrustes: rmse 0.1883577  max resid 0.5697554
# Run 7 stress 0.1531268
# ... Procrustes: rmse 0.1883261  max resid 0.5697011
# Run 8 stress 0.158719
# Run 9 stress 0.1523922
# ... New best solution
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.24175 0.241748    3.22 0.18699 0.1635
# Residuals                 14   1.05108 0.075077         0.81301
# Total                     15   1.29283                  1.00000
# ```
# ###NMDS using raup
# ![alt text](m4a_raw.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4465 0.44648   1.004 0.06691 0.4731
# Residuals                 14    6.2259 0.44471         0.93309
# Total                     15    6.6724                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](m4a_raw.Treatment.braycurtis.pdf)

# %%
#convert no subtraction to biom
# !amptk taxonomy -f m4a_nosub.filtered.otus.fa -o m4a_nosub -i m4a_nosub.final.txt -d ITS2 -m m4a.mapping_file.txt
# Out:
# -------------------------------------------------------
# [05:08:58 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [05:08:58 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [05:08:58 PM]: Loading FASTA Records
# [05:08:58 PM]: 1,752 OTUs
# [05:08:58 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [05:09:14 PM]: Classifying OTUs with UTAX (USEARCH)
# [05:09:15 PM]: Classifying OTUs with SINTAX (USEARCH)
# [05:13:37 PM]: Appending taxonomy to OTU table and OTUs
# [05:13:37 PM]: Generating phylogenetic tree
# [05:13:43 PM]: Taxonomy finished: m4a_nosub.taxonomy.txt
# [05:13:43 PM]: Classic OTU table with taxonomy: m4a_nosub.otu_table.taxonomy.txt
# [05:13:45 PM]: BIOM OTU table created: m4a_nosub.biom
# [05:13:45 PM]: OTUs with taxonomy: m4a_nosub.otus.taxonomy.fa
# [05:13:45 PM]: OTU phylogeny: m4a_nosub.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R m4a_nosub.biom m4a_nosub.tree.phy m4a_nosub
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1536324
# Run 1 stress 0.1546032
# Run 2 stress 0.1608357
# Run 3 stress 0.1536345
# ... Procrustes: rmse 0.0008581549  max resid 0.001926481
# ... Similar to previous best
# Run 4 stress 0.1546048
# Run 5 stress 0.1906837
# Run 6 stress 0.1536372
# ... Procrustes: rmse 0.001780999  max resid 0.004182533
# ... Similar to previous best
# Run 7 stress 0.2052105
# Run 8 stress 0.1698431
# Run 9 stress 0.1546039
# Run 10 stress 0.1672919
# Run 11 stress 0.1536324
# ... New best solution
# ... Procrustes: rmse 0.0003885178  max resid 0.0006440897
# ... Similar to previous best
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick & 0.1% default index bleed filtering
# ```
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.52174 0.52174  5.1197 0.26777 0.0459 *
# Residuals                 14   1.42672 0.10191         0.73223
# Total                     15   1.94847                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###Treatment adonis using raupcrick & 0.5% index bleed filtering
# ```
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.39228 0.39228  2.5804 0.15563 0.1536
# Residuals                 14   2.12830 0.15202         0.84437
# Total                     15   2.52058                 1.00000
# ```
#
# ###NMDS using raup
# ![alt text](m4a_nosub.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis & 0.1% index bleed filter
# ```
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4461 0.44611  1.0011 0.06673 0.4874
# Residuals                 14    6.2388 0.44563         0.93327
# Total                     15    6.6850                 1.00000
# ```
# ###Treatment adonis using braycurtis & 0.5% index bleed filter
# ```
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4458 0.44585 0.99818 0.06655 0.4935
# Residuals                 14    6.2532 0.44666         0.93345
# Total                     15    6.6991                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](m4a_nosub.Treatment.braycurtis.pdf)

# %%
#filter with subtraction
# !amptk filter -i m4a.otu_table.txt -f m4a.cluster.otus.fa -b m4A-mock3-16000 -m mock3 -c in -o m4a -s auto -p 0.005
# Out:
# -------------------------------------------------------
# [05:16:34 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [05:16:34 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [05:16:34 PM]: Loading OTU table: m4a.otu_table.txt
# [05:16:34 PM]: OTU table contains 1798 OTUs
# [05:16:34 PM]: Mapping OTUs to Mock Community (USEARCH)
# [05:16:34 PM]: Sorting OTU table naturally
# [05:16:34 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [05:16:34 PM]: Normalizing OTU table to number of reads per sample
# [05:16:34 PM]: Index bleed, samples into mock: 0.054001%.
# [05:16:34 PM]: Overwriting auto detect index-bleed, setting to 0.500000%
# [05:16:34 PM]: Auto subtract filter set to 25
# [05:16:34 PM]: Subtracting 25 from OTU table
# [05:16:34 PM]: Filtering OTU table down to 436 OTUs
# [05:16:34 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# ...

# %%
#convert to biom
# !amptk taxonomy -f m4a.filtered.otus.fa -o m4a -i m4a.final.txt -d ITS2 -m m4a.mapping_file.txt
# Out:
# -------------------------------------------------------
# [05:16:48 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [05:16:48 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [05:16:48 PM]: Loading FASTA Records
# [05:16:48 PM]: 436 OTUs
# [05:16:48 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [05:16:54 PM]: Classifying OTUs with UTAX (USEARCH)
# [05:16:54 PM]: Classifying OTUs with SINTAX (USEARCH)
# [05:18:30 PM]: Appending taxonomy to OTU table and OTUs
# [05:18:30 PM]: Generating phylogenetic tree
# [05:18:30 PM]: Taxonomy finished: m4a.taxonomy.txt
# [05:18:30 PM]: Classic OTU table with taxonomy: m4a.otu_table.taxonomy.txt
# [05:18:31 PM]: BIOM OTU table created: m4a.biom
# [05:18:31 PM]: OTUs with taxonomy: m4a.otus.taxonomy.fa
# [05:18:31 PM]: OTU phylogeny: m4a.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R m4a.biom m4a.tree.phy m4a
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.2025629
# Run 1 stress 0.2333422
# Run 2 stress 0.2136412
# Run 3 stress 0.2186079
# Run 4 stress 0.2462678
# Run 5 stress 0.2365634
# Run 6 stress 0.2025629
# ... Procrustes: rmse 1.153241e-05  max resid 3.076636e-05
# ... Similar to previous best
# Run 7 stress 0.2541619
# Run 8 stress 0.2025629
# ... New best solution
# ... Procrustes: rmse 2.990079e-06  max resid 6.854737e-06
# ... Similar to previous best
# Run 9 stress 0.2468372
# Run 10 stress 0.2147798
# Run 11 stress 0.2197034
# Run 12 stress 0.2157279
# Run 13 stress 0.2087092
# Run 14 stress 0.2288752
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick & 0.1% index bleed
# ```
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.58272 0.58272  3.3115 0.19129 0.0416 *
# Residuals                 14   2.46355 0.17597         0.80871
# Total                     15   3.04627                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###Treatment adonis using raupcrick & 0.5% index bleed
# ```
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.59365 0.59365  3.3044 0.19096 0.0418 *
# Residuals                 14   2.51518 0.17966         0.80904
# Total                     15   3.10883                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###NMDS using raup
# ![alt text](m4a.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis & 0.1% index bleed
# ```
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4473 0.44733 0.99773 0.06653  0.481
# Residuals                 14    6.2769 0.44835         0.93347
# Total                     15    6.7242                 1.00000
# ```
# ###Treatment adonis using braycurtis & 0.5% index bleed
# ```
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4471 0.44709 0.99609 0.06642  0.493
# Residuals                 14    6.2838 0.44884         0.93358
# Total                     15    6.7309                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](m4a.Treatment.braycurtis.pdf)

# %%
#now run miseqC run
#now lets go back and process each of these runs separately, i.e. akin to how you would normally run amptk
#first select the reads you want from original demuxing
# !amptk remove -i m4c.demux.fq -l m4C-mock3-32000b m4C-mock3-32000a m4C-stds -o miseq4c.cleaned.demux.fq
# !amptk show -i miseq4c.cleaned.demux.fq
# Out:
# Removed 3 samples
# Kept 5159926 reads out of 6069913 total reads
# ----------------------------------
# Found 17 barcoded samples
#               Sample:  Count
#            m4C-757-2:  390122
#            m4C-301-2:  385896
#            m4C-755-2:  351946
#            m4C-736-2:  314792
#            m4C-301-1:  312792
#            m4C-757-1:  310890
#            m4C-712-1:  306776
#            m4C-712-2:  300925
#      m4C-mock3-16000:  299132
#            m4C-500-1:  299131
#            m4C-500-2:  297249
#            m4C-736-1:  288079
#            m4C-766-1:  284263
#            m4C-755-1:  280033
#            m4C-744-1:  262240
#            m4C-766-2:  255491
#            m4C-744-2:  220169
# ----------------------------------
# Read count: 5159926
# Read Length: 250 bp
# ----------------------------------

# %%
#now cluster the cleaned up data
# !amptk cluster -i miseq4c.cleaned.demux.fq -o m4c
# Out:
# -------------------------------------------------------
# [04:11:20 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [04:11:21 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [04:11:21 PM]: Loading FASTQ Records
# [04:11:24 PM]: 5,159,926 reads (2.6 GB)
# [04:11:24 PM]: Quality Filtering, expected errors < 1.0
# [04:13:23 PM]: 3,324,712 reads passed
# [04:13:23 PM]: De-replication (remove duplicate reads)
# [04:13:34 PM]: 178,499 reads passed
# [04:13:35 PM]: Clustering OTUs (UPARSE)
# [04:13:48 PM]: 1,623 OTUs
# [04:13:48 PM]: Cleaning up padding from OTUs
# [04:13:48 PM]: Mapping Reads to OTUs and Building OTU table
# [04:24:15 PM]: 3,878,003 reads mapped to OTUs (75%)
# -------------------------------------------------------
# OTU Clustering Script has Finished Successfully
# -------------------------------------------------------
# Clustered OTUs: /Users/jon/projects/synmock_paper/m4c.cluster.otus.fa
# ...

# %%
#run filtering with no subtraction first
# !amptk filter -i m4c.otu_table.txt -f m4c.cluster.otus.fa -b m4C-mock3-16000 -m mock3 -c in -o m4c_nosub -p 0.005
# Out:
# -------------------------------------------------------
# [05:22:14 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [05:22:14 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [05:22:14 PM]: Loading OTU table: m4c.otu_table.txt
# [05:22:14 PM]: OTU table contains 1623 OTUs
# [05:22:14 PM]: Mapping OTUs to Mock Community (USEARCH)
# [05:22:15 PM]: Sorting OTU table naturally
# [05:22:15 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [05:22:15 PM]: Normalizing OTU table to number of reads per sample
# [05:22:15 PM]: Index bleed, samples into mock: 0.050002%.
# [05:22:15 PM]: Overwriting auto detect index-bleed, setting to 0.500000%
# [05:22:15 PM]: Filtering OTU table down to 1593 OTUs
# [05:22:15 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# -------------------------------------------------------
# OTU Table Stats:      m4c_nosub.stats.txt
# ...

# %%
#get raw data into biom format
import pandas as pd
from natsort import natsorted
#pull out header for indexing later
with open('m4c_nosub.sorted.txt', 'rU') as f:
    first_line = f.readline()
    OTUhead = first_line.split('\t')[0]
    
#now load sorted "raw" OTU table into dataframe
dfsorted = pd.read_csv('m4c_nosub.sorted.txt', sep='\t')
dfsorted.set_index(OTUhead, inplace=True)

#now we want to drop last column
header = ['m4C-301-1', 'm4C-301-2', 'm4C-500-1', 'm4C-500-2', 'm4C-712-1', 
           'm4C-712-2', 'm4C-736-1', 'm4C-736-2', 'm4C-744-1', 'm4C-744-2', 
           'm4C-755-1', 'm4C-755-2', 'm4C-757-1', 'm4C-757-2', 'm4C-766-1', 'm4C-766-2']
dfcleaned = dfsorted.reindex(columns=header, index=natsorted(dfsorted.index))

#now drop OTUs where they are all zero
fs = dfcleaned.sum(axis=0)
filtered = pd.DataFrame(dfcleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(dfsorted), len(dfsorted.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv('m4c.sorted.nomock.txt', sep='\t')

#now convert to biom
# !amptk taxonomy -f m4c.cluster.otus.fa -o m4c_raw -i m4c.sorted.nomock.txt -d ITS2 -m m4c.mapping_file.txt
# Out:
# 1623 17 1622 16
# -------------------------------------------------------
# [04:24:18 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [04:24:19 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [04:24:19 PM]: Loading FASTA Records
# [04:24:19 PM]: 1,623 OTUs
# [04:24:19 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [04:24:36 PM]: Classifying OTUs with UTAX (USEARCH)
# [04:24:36 PM]: Classifying OTUs with SINTAX (USEARCH)
# [04:28:44 PM]: Appending taxonomy to OTU table and OTUs
# [04:28:44 PM]: Generating phylogenetic tree
# [04:28:50 PM]: Taxonomy finished: m4c_raw.taxonomy.txt
# [04:28:50 PM]: Classic OTU table with taxonomy: m4c_raw.otu_table.taxonomy.txt
# [04:28:51 PM]: BIOM OTU table created: m4c_raw.biom
# [04:28:51 PM]: OTUs with taxonomy: m4c_raw.otus.taxonomy.fa
# [04:28:51 PM]: OTU phylogeny: m4c_raw.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R m4c_raw.biom m4c_raw.tree.phy m4c_raw
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# There were 26 warnings (use warnings() to see them)
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.147573
# Run 1 stress 0.1482371
# Run 2 stress 0.1797045
# Run 3 stress 0.147573
# ... Procrustes: rmse 2.710139e-05  max resid 7.020399e-05
# ... Similar to previous best
# Run 4 stress 0.154546
# Run 5 stress 0.1482371
# Run 6 stress 0.1484346
# Run 7 stress 0.147573
# ... New best solution
# ... Procrustes: rmse 5.294917e-05  max resid 0.0001201151
# ... Similar to previous best
# Run 8 stress 0.1545458
# Run 9 stress 0.1527002
# Run 10 stress 0.1966284
# Run 11 stress 0.1640424
# Run 12 stress 0.1734689
# Run 13 stress 0.147573
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.62465 0.62465  11.135 0.44301  0.008 **
# Residuals                 14   0.78535 0.05610         0.55699
# Total                     15   1.41000                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###NMDS using raup
# ![alt text](m4c_raw.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4464 0.44636 0.99684 0.06647  0.496
# Residuals                 14    6.2688 0.44777         0.93353
# Total                     15    6.7152                 1.00000
#
# ```
# ###NMDS using braycurtis
# ![alt text](m4c_raw.Treatment.braycurtis.pdf)

# %%
#convert no subtraction to biom
# !amptk taxonomy -f m4c_nosub.filtered.otus.fa -o m4c_nosub -i m4c_nosub.final.txt -d ITS2 -m m4c.mapping_file.txt
# Out:
# -------------------------------------------------------
# [05:22:40 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [05:22:40 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [05:22:40 PM]: Loading FASTA Records
# [05:22:40 PM]: 1,593 OTUs
# [05:22:40 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [05:22:55 PM]: Classifying OTUs with UTAX (USEARCH)
# [05:22:56 PM]: Classifying OTUs with SINTAX (USEARCH)
# [05:26:50 PM]: Appending taxonomy to OTU table and OTUs
# [05:26:50 PM]: Generating phylogenetic tree
# [05:26:55 PM]: Taxonomy finished: m4c_nosub.taxonomy.txt
# [05:26:55 PM]: Classic OTU table with taxonomy: m4c_nosub.otu_table.taxonomy.txt
# [05:26:57 PM]: BIOM OTU table created: m4c_nosub.biom
# [05:26:57 PM]: OTUs with taxonomy: m4c_nosub.otus.taxonomy.fa
# [05:26:57 PM]: OTU phylogeny: m4c_nosub.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R m4c_nosub.biom m4c_nosub.tree.phy m4c_nosub
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.1589888
# Run 1 stress 0.1660641
# Run 2 stress 0.2309605
# Run 3 stress 0.1660634
# Run 4 stress 0.2125066
# Run 5 stress 0.1589888
# ... New best solution
# ... Procrustes: rmse 1.124799e-05  max resid 3.178494e-05
# ... Similar to previous best
# Run 6 stress 0.1660633
# Run 7 stress 0.1707548
# Run 8 stress 0.1707548
# Run 9 stress 0.1684414
# Run 10 stress 0.1825581
# Run 11 stress 0.1589888
# ... Procrustes: rmse 2.971052e-06  max resid 7.156171e-06
# ... Similar to previous best
# Run 12 stress 0.2138665
# Run 13 stress 0.1589888
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.47165 0.47165  4.3805 0.23832 0.0663 .
# Residuals                 14   1.50738 0.10767         0.76168
# Total                     15   1.97904                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
#
# ```
#                           Df SumsOfSqs MeanSqs F.Model    R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.27439 0.27439    1.66 0.106 0.2647
# Residuals                 14   2.31415 0.16530         0.894
# Total                     15   2.58854                 1.000
# ```
# ###NMDS using raup
# ![alt text](m4c_nosub.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4455 0.44548 0.99282 0.06622 0.4981
# Residuals                 14    6.2818 0.44870         0.93378
# Total                     15    6.7273                 1.00000
#
# ```
# ###NMDS using braycurtis
# ![alt text](m4c_nosub.Treatment.braycurtis.pdf)

# %%
#filter with subtraction
# !amptk filter -i m4c.otu_table.txt -f m4c.cluster.otus.fa -b m4C-mock3-16000 -m mock3 -c in -o m4c -s auto
# Out:
# -------------------------------------------------------
# [04:34:10 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [04:34:11 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [04:34:11 PM]: Loading OTU table: m4c.otu_table.txt
# [04:34:11 PM]: OTU table contains 1623 OTUs
# [04:34:11 PM]: Mapping OTUs to Mock Community (USEARCH)
# [04:34:11 PM]: Sorting OTU table naturally
# [04:34:11 PM]: Removing OTUs according to --min_reads_otu: (OTUs with less than 2 reads from all samples)
# [04:34:11 PM]: Normalizing OTU table to number of reads per sample
# [04:34:11 PM]: Index bleed, samples into mock: 0.050002%.
# [04:34:11 PM]: Will use value of 0.100000% for index-bleed OTU filtering.
# [04:34:11 PM]: Auto subtract filter set to 17
# [04:34:11 PM]: Subtracting 17 from OTU table
# [04:34:11 PM]: Filtering OTU table down to 486 OTUs
# [04:34:11 PM]: Filtering valid OTUs
# -------------------------------------------------------
# OTU Table filtering finished
# ...

# %%
#convert subtraction to biom
# !amptk taxonomy -f m4c.filtered.otus.fa -o m4c -i m4c.final.txt -d ITS2 -m m4c.mapping_file.txt
# Out:
# -------------------------------------------------------
# [04:34:12 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# [04:34:12 PM]: amptk v.0.8.9, USEARCH v9.2.64, VSEARCH v2.4.2
# [04:34:12 PM]: Loading FASTA Records
# [04:34:12 PM]: 486 OTUs
# [04:34:12 PM]: Global alignment OTUs with usearch_global (USEARCH)
# [04:34:18 PM]: Classifying OTUs with UTAX (USEARCH)
# [04:34:18 PM]: Classifying OTUs with SINTAX (USEARCH)
# [04:36:05 PM]: Appending taxonomy to OTU table and OTUs
# [04:36:05 PM]: Generating phylogenetic tree
# [04:36:06 PM]: Taxonomy finished: m4c.taxonomy.txt
# [04:36:06 PM]: Classic OTU table with taxonomy: m4c.otu_table.taxonomy.txt
# [04:36:07 PM]: BIOM OTU table created: m4c.biom
# [04:36:07 PM]: OTUs with taxonomy: m4c.otus.taxonomy.fa
# [04:36:07 PM]: OTU phylogeny: m4c.tree.phy
# -------------------------------------------------------

# %%
#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R m4c.biom m4c.tree.phy m4c
# Out:
# Loading required package: phyloseq
# Loading required package: methods
# Loading required package: ggplot2
# Loading required package: plyr
# Loading required package: vegan
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.4-2
# [1] ‘1.19.1’
# [1] ‘2.2.1’
# [1] ‘1.8.4’
# [1] ‘2.4.2’
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.2044775
# Run 1 stress 0.2188196
# Run 2 stress 0.2036105
# ... New best solution
# ... Procrustes: rmse 0.1435263  max resid 0.3988433
# Run 3 stress 0.2106685
# Run 4 stress 0.2106687
# Run 5 stress 0.2225292
# Run 6 stress 0.2161192
# Run 7 stress 0.2168716
# Run 8 stress 0.221025
# Run 9 stress 0.2169447
# Run 10 stress 0.2044787
# Run 11 stress 0.21681
# Run 12 stress 0.2199021
# Run 13 stress 0.2044759
# Run 14 stress 0.218723
# Run 15 stress 0.2044773
# Run 16 stress 0.2220565
# Run 17 stress 0.2151821
# Run 18 stress 0.2161192
# Run 19 stress 0.2242043
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.58201 0.58201  3.7066 0.20933 0.0362 *
# Residuals                 14   2.19831 0.15702         0.79067
# Total                     15   2.78032                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ```
# ###NMDS using raup
# ![alt text](m4c_nosub.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4467 0.44667 0.99108 0.06611 0.4972
# Residuals                 14    6.3097 0.45069         0.93389
# Total                     15    6.7563                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](m4c_nosub.Treatment.braycurtis.pdf)

# %%
#now onto ion5 synmock run
#now lets go back and process each of these runs separately, i.e. akin to how you would normally run amptk
#first select the reads you want from original demuxing
# !amptk remove -i ion5.demux.fq -l m5-SynMock1-8000 m5-mock3.5-16000 m5-mock3.0-16000 -o ion5.cleaned.demux.fq
# !amptk show -i ion5.cleaned.demux.fq
# !amptk cluster -i ion5.cleaned.demux.fq -o i5
# !amptk filter -i i5.otu_table.txt -f i5.cluster.otus.fa -b m5-SynMock2-8000 -m synmock -o i5_nosub

#get raw data into biom format
import pandas as pd
from natsort import natsorted
#pull out header for indexing later
with open('i5_nosub.sorted.txt', 'rU') as f:
    first_line = f.readline()
    OTUhead = first_line.split('\t')[0]
    
#now load sorted "raw" OTU table into dataframe
dfsorted = pd.read_csv('i5_nosub.sorted.txt', sep='\t')
dfsorted.set_index(OTUhead, inplace=True)

#now we want to drop last column
header = ['m5-301-1', 'm5-301-2', 'm5-500-1', 'm5-500-2', 'm5-712-1', 
        'm5-712-2', 'm5-736-1', 'm5-736-2', 'm5-744-1', 'm5-744-2', 
        'm5-755-1', 'm5-755-2', 'm5-757-1', 'm5-757-2', 'm5-766-1', 'm5-766-2']
dfcleaned = dfsorted.reindex(columns=header, index=natsorted(dfsorted.index))

#now drop OTUs where they are all zero
fs = dfcleaned.sum(axis=0)
filtered = pd.DataFrame(dfcleaned, columns=fs.index)
filt2 = filtered.loc[(filtered != 0).any(1)]
print len(dfsorted), len(dfsorted.columns.values), len(filt2), len(filt2.columns.values)
filt2.to_csv('i5.sorted.nomock.txt', sep='\t')

#now convert to biom
# !amptk taxonomy -f i5.cluster.otus.fa -o i5_raw -i i5.sorted.nomock.txt -d ITS2 -m ion5.mapping_file.txt

#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R i5_raw.biom i5_raw.tree.phy i5_raw

#convert no subtraction to biom
# !amptk taxonomy -f i5_nosub.filtered.otus.fa -o i5_nosub -i i5_nosub.final.txt -d ITS2 -m ion5.mapping_file.txt

#run phyloseq stats
# !/Users/jon/amptk/util/phyloseq_graphs.R i5_nosub.biom i5_nosub.tree.phy i5_nosub
# Out:
# Removed 3 samples
# Kept 1914908 reads out of 2227883 total reads
# ----------------------------------
# Found 17 barcoded samples
#               Sample:  Count
#             m5-712-2:  232495
#             m5-301-2:  186706
#             m5-301-1:  173161
#             m5-500-1:  159088
#             m5-744-2:  115363
#             m5-736-2:  110748
#             m5-757-1:  108256
#             m5-757-2:  107142
#             m5-755-1:  104765
#             m5-736-1:  93187
#             m5-766-1:  86246
#             m5-755-2:  81537
#             m5-766-2:  79478
#             m5-744-1:  79267
#     m5-SynMock2-8000:  71677
#             m5-712-1:  71344
#             m5-500-2:  54448
# ----------------------------------
# Read count: 1914908
# Read Length: 250 bp
# ----------------------------------
# -------------------------------------------------------
# [04:39:33 PM]: OS: MacOSX 10.12.3, 8 cores, ~ 16 GB RAM. Python: 2.7.12
# ...

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1   0.24521 0.245208   3.296 0.19057 0.1604
# Residuals                 14   1.04153 0.074395         0.80943
# Total                     15   1.28674                  1.00000
# ```
# ###NMDS using raup
# ![alt text](i5_raw.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4415 0.44148 0.96188 0.06429 0.5508
# Residuals                 14    6.4257 0.45898         0.93571
# Total                     15    6.8672                 1.00000
# ```
# ###NMDS using braycurtis
# ![alt text](i5_raw.Treatment.braycurtis.pdf)

# %% [markdown]
# ###Treatment adonis using raupcrick
# ```
# Call:
# adonis(formula = rp ~ metadata[[treatments[y]]], permutations = 9999)
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# metadata[[treatments[y]]]  1     0.346  0.3460  3.8232 0.21451 0.0948 .
# Residuals                 14     1.267  0.0905         0.78549
# Total                     15     1.613                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ```
# ###NMDS using raup
# ![alt text](i5_nosub.Treatment.raup.pdf)
# ###Treatment adonis using braycurtis
# ```
# Call:
# adonis(formula = voturaw ~ metadata[[treatments[y]]], permutations = 9999,      method = "bray")
#
# Permutation: free
# Number of permutations: 9999
#
# Terms added sequentially (first to last)
#
#                           Df SumsOfSqs MeanSqs F.Model     R2 Pr(>F)
# metadata[[treatments[y]]]  1    0.4420 0.44197 0.96205 0.0643 0.5583
# Residuals                 14    6.4317 0.45941         0.9357
# Total                     15    6.8737                 1.0000
#
# ```
# ###NMDS using braycurtis
# ![alt text](i5_nosub.Treatment.braycurtis.pdf)
